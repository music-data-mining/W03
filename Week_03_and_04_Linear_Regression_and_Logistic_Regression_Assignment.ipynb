# %% [markdown]
# # Week 03/Week 04 Linear Regression and Logistic Regression Assignment

# %% [markdown]
# - Course: Z604 Music Data Mining
# - Instructor: Kahyun Choi

# %% [markdown]
# Download data files and helper scripts of the week from GitHub

# %%
# if you meet "fatal: destination path 'W04' already exists and is not an empty directory" error, uncomment the line below and run again
# !rm -fr W04/
# !git clone https://github.com/music-data-mining/W04.git

# %%
# go to the directory of the week
# %cd W04

# %% [markdown]
# # Setup

# %%
# Common imports
import os
import numpy as np
import pandas as pd
from scipy import stats

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ## Exploring Deezer MSD Mood Dataset II (Three N dimensional MSD Features -- timbre, chroma, and loudness)

# %% [markdown]
# ### Load moodmsdfeatures.csv

# %%
data = pd.read_csv('moodmsdfeatures.csv')  # load data set

# %%
data.head() # Return the first 5 rows
# Out:
#    dzr_sng_id          MSD_sng_id  ... loudness  quadrant
# 0      560270  SOTFUBR12A8C13E3EC  ...   -5.509         4
# 1      560274  SOULDME12AB01887C6  ...   -9.000         4
# 2      623060  SOAYOFO12AF72A4B88  ...   -1.810         4
# 3      916339  SOOOWIC12A6701C7E5  ...   -4.430         1
# 4      916480  SOJCBAM12A6701FD04  ...   -6.966         4
#
# [5 rows x 11 columns]

# %%
data.info() # get a quick description of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 11 columns):
# dzr_sng_id      224 non-null int64
# MSD_sng_id      224 non-null object
# MSD_track_id    224 non-null object
# valence         224 non-null float64
# arousal         224 non-null float64
# artist_name     224 non-null object
# track_name      224 non-null object
# mode            224 non-null int64
# tempo           224 non-null float64
# loudness        224 non-null float64
# quadrant        224 non-null int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 19.4+ KB

# %% [markdown]
# ### Load MSD timbre, chroma, and loudmax features and Caculate Their Means and Variances

# %%
import csv
import hdf5_getters

songreader = csv.DictReader(open('moodmsdfeatures.csv'))

timbre_mean = np.empty((0,12), dtype=float)
timbre_var = np.empty((0,12), dtype=float)
chroma_mean = np.empty((0,12), dtype=float)
chroma_var = np.empty((0,12), dtype=float)
loudmax_mean = np.empty((0,1), dtype=float)
loudmax_var = np.empty((0,1), dtype=float)

for song in songreader:
    trid = song['MSD_track_id']
    filename = 'deezer_MSD/' + trid + '.h5'
    h5 = hdf5_getters.open_h5_file_read(filename)
    print("filename: ",filename)
    timbre = hdf5_getters.get_segments_timbre(h5)
    print("timbre.shape: ",timbre.shape)
    timbre_mean = np.vstack((timbre_mean, np.mean(timbre, axis = 0)))
    print("timbre_mean.shape: ",timbre_mean.shape)
    timbre_var = np.vstack((timbre_var, np.var(timbre, axis = 0)))
    print("timbre_var.shape: ",timbre_var.shape)
    chroma = hdf5_getters.get_segments_pitches(h5)
    chroma_mean = np.vstack((chroma_mean, np.mean(chroma, axis = 0)))
    chroma_var = np.vstack((chroma_var, np.var(chroma, axis = 0)))
    loudmax = hdf5_getters.get_segments_loudness_max(h5)
    loudmax_mean = np.vstack((loudmax_mean, np.mean(loudmax, axis = 0)))
    loudmax_var = np.vstack((loudmax_var, np.var(loudmax, axis = 0)))
# Out:
# filename:  deezer_MSD/TRAYKVH128F42AC993.h5
# timbre.shape:  (966, 12)
# timbre_mean.shape:  (1, 12)
# timbre_var.shape:  (1, 12)
# filename:  deezer_MSD/TRATCMK12903CABAC8.h5
# timbre.shape:  (1084, 12)
# timbre_mean.shape:  (2, 12)
# timbre_var.shape:  (2, 12)
# filename:  deezer_MSD/TRALJBT128F4266FD8.h5
# timbre.shape:  (1077, 12)
# timbre_mean.shape:  (3, 12)
# timbre_var.shape:  (3, 12)
# filename:  deezer_MSD/TRBGPJP128E078ED20.h5
# timbre.shape:  (843, 12)
# timbre_mean.shape:  (4, 12)
# timbre_var.shape:  (4, 12)
# filename:  deezer_MSD/TRAGFPP128E078F34C.h5
# timbre.shape:  (927, 12)
# timbre_mean.shape:  (5, 12)
# timbre_var.shape:  (5, 12)
# filename:  deezer_MSD/TRAXLPR128F428E466.h5
# timbre.shape:  (732, 12)
# timbre_mean.shape:  (6, 12)
# timbre_var.shape:  (6, 12)
# filename:  deezer_MSD/TRBBAHD128F428E0FE.h5
# timbre.shape:  (900, 12)
# timbre_mean.shape:  (7, 12)
# timbre_var.shape:  (7, 12)
# filename:  deezer_MSD/TRBHLDQ128F423EF10.h5
# timbre.shape:  (559, 12)
# timbre_mean.shape:  (8, 12)
# timbre_var.shape:  (8, 12)
# filename:  deezer_MSD/TRABCUQ128E0783E2B.h5
# timbre.shape:  (1212, 12)
# timbre_mean.shape:  (9, 12)
# timbre_var.shape:  (9, 12)
# filename:  deezer_MSD/TRBCBXZ128F14628C3.h5
# timbre.shape:  (996, 12)
# timbre_mean.shape:  (10, 12)
# timbre_var.shape:  (10, 12)
# filename:  deezer_MSD/TRBGNCL128F428F56F.h5
# timbre.shape:  (1354, 12)
# timbre_mean.shape:  (11, 12)
# timbre_var.shape:  (11, 12)
# filename:  deezer_MSD/TRAVJHK128E078370B.h5
# timbre.shape:  (980, 12)
# timbre_mean.shape:  (12, 12)
# timbre_var.shape:  (12, 12)
# filename:  deezer_MSD/TRAKHYP128E0792F07.h5
# timbre.shape:  (562, 12)
# timbre_mean.shape:  (13, 12)
# timbre_var.shape:  (13, 12)
# filename:  deezer_MSD/TRBCKSF128F932FA70.h5
# timbre.shape:  (832, 12)
# timbre_mean.shape:  (14, 12)
# timbre_var.shape:  (14, 12)
# filename:  deezer_MSD/TRAMVOM128F42ACB16.h5
# timbre.shape:  (1258, 12)
# timbre_mean.shape:  (15, 12)
# timbre_var.shape:  (15, 12)
# filename:  deezer_MSD/TRAFSIP128F9301AE9.h5
# timbre.shape:  (730, 12)
# timbre_mean.shape:  (16, 12)
# timbre_var.shape:  (16, 12)
# filename:  deezer_MSD/TRAPMRV128F92F5F4C.h5
# timbre.shape:  (737, 12)
# timbre_mean.shape:  (17, 12)
# timbre_var.shape:  (17, 12)
# filename:  deezer_MSD/TRANBUW128F933C645.h5
# timbre.shape:  (481, 12)
# timbre_mean.shape:  (18, 12)
# timbre_var.shape:  (18, 12)
# filename:  deezer_MSD/TRBFURI128F1455498.h5
# timbre.shape:  (630, 12)
# timbre_mean.shape:  (19, 12)
# timbre_var.shape:  (19, 12)
# filename:  deezer_MSD/TRBFLIP128E07897B4.h5
# timbre.shape:  (803, 12)
# timbre_mean.shape:  (20, 12)
# timbre_var.shape:  (20, 12)
# filename:  deezer_MSD/TRANAHT128E07895F8.h5
# timbre.shape:  (880, 12)
# timbre_mean.shape:  (21, 12)
# timbre_var.shape:  (21, 12)
# filename:  deezer_MSD/TRAMRZO12903CA82FB.h5
# timbre.shape:  (545, 12)
# timbre_mean.shape:  (22, 12)
# timbre_var.shape:  (22, 12)
# filename:  deezer_MSD/TRAQVOG128F9340E58.h5
# timbre.shape:  (702, 12)
# timbre_mean.shape:  (23, 12)
# timbre_var.shape:  (23, 12)
# filename:  deezer_MSD/TRAUXEU12903CD3CD7.h5
# timbre.shape:  (701, 12)
# timbre_mean.shape:  (24, 12)
# timbre_var.shape:  (24, 12)
# filename:  deezer_MSD/TRBDUXD128F148328A.h5
# timbre.shape:  (1114, 12)
# timbre_mean.shape:  (25, 12)
# timbre_var.shape:  (25, 12)
# filename:  deezer_MSD/TRANVZT128F42AE134.h5
# timbre.shape:  (921, 12)
# timbre_mean.shape:  (26, 12)
# timbre_var.shape:  (26, 12)
# filename:  deezer_MSD/TRAACER128F4290F96.h5
# timbre.shape:  (719, 12)
# timbre_mean.shape:  (27, 12)
# timbre_var.shape:  (27, 12)
# filename:  deezer_MSD/TRAYJHF128F4294CB8.h5
# timbre.shape:  (1024, 12)
# timbre_mean.shape:  (28, 12)
# timbre_var.shape:  (28, 12)
# filename:  deezer_MSD/TRADCHC128F42134B5.h5
# timbre.shape:  (1165, 12)
# timbre_mean.shape:  (29, 12)
# timbre_var.shape:  (29, 12)
# filename:  deezer_MSD/TRBGASN128F427BF8F.h5
# timbre.shape:  (1026, 12)
# timbre_mean.shape:  (30, 12)
# timbre_var.shape:  (30, 12)
# filename:  deezer_MSD/TRBAOTY128F9327A9C.h5
# timbre.shape:  (787, 12)
# timbre_mean.shape:  (31, 12)
# timbre_var.shape:  (31, 12)
# filename:  deezer_MSD/TRAVGZS128F9338603.h5
# timbre.shape:  (369, 12)
# timbre_mean.shape:  (32, 12)
# timbre_var.shape:  (32, 12)
# filename:  deezer_MSD/TRAASUZ128F9314950.h5
# timbre.shape:  (727, 12)
# timbre_mean.shape:  (33, 12)
# timbre_var.shape:  (33, 12)
# filename:  deezer_MSD/TRBAWKB128F931BAEE.h5
# timbre.shape:  (1333, 12)
# timbre_mean.shape:  (34, 12)
# timbre_var.shape:  (34, 12)
# filename:  deezer_MSD/TRADJGI128F148B0F6.h5
# timbre.shape:  (694, 12)
# timbre_mean.shape:  (35, 12)
# timbre_var.shape:  (35, 12)
# filename:  deezer_MSD/TRBEBEZ128E0792F08.h5
# timbre.shape:  (539, 12)
# timbre_mean.shape:  (36, 12)
# timbre_var.shape:  (36, 12)
# filename:  deezer_MSD/TRADRJK128E078F041.h5
# timbre.shape:  (808, 12)
# timbre_mean.shape:  (37, 12)
# timbre_var.shape:  (37, 12)
# filename:  deezer_MSD/TRBFMAS128E078F352.h5
# timbre.shape:  (744, 12)
# timbre_mean.shape:  (38, 12)
# timbre_var.shape:  (38, 12)
# filename:  deezer_MSD/TRASXZE128F427F156.h5
# timbre.shape:  (773, 12)
# timbre_mean.shape:  (39, 12)
# timbre_var.shape:  (39, 12)
# filename:  deezer_MSD/TRBCJSZ128E07969B5.h5
# timbre.shape:  (811, 12)
# timbre_mean.shape:  (40, 12)
# timbre_var.shape:  (40, 12)
# filename:  deezer_MSD/TRAKPHP128F42807B0.h5
# timbre.shape:  (810, 12)
# timbre_mean.shape:  (41, 12)
# timbre_var.shape:  (41, 12)
# filename:  deezer_MSD/TRAGPAF128EF34542A.h5
# timbre.shape:  (485, 12)
# timbre_mean.shape:  (42, 12)
# timbre_var.shape:  (42, 12)
# filename:  deezer_MSD/TRAPDOI128F9327982.h5
# timbre.shape:  (1526, 12)
# timbre_mean.shape:  (43, 12)
# timbre_var.shape:  (43, 12)
# filename:  deezer_MSD/TRAPCNK128F427D7B5.h5
# timbre.shape:  (335, 12)
# timbre_mean.shape:  (44, 12)
# timbre_var.shape:  (44, 12)
# filename:  deezer_MSD/TRAMFAS12903CD7030.h5
# timbre.shape:  (2094, 12)
# timbre_mean.shape:  (45, 12)
# timbre_var.shape:  (45, 12)
# filename:  deezer_MSD/TRAGFVT128F92ECB5D.h5
# timbre.shape:  (809, 12)
# timbre_mean.shape:  (46, 12)
# timbre_var.shape:  (46, 12)
# filename:  deezer_MSD/TRAAMES128F42AF068.h5
# timbre.shape:  (1097, 12)
# timbre_mean.shape:  (47, 12)
# timbre_var.shape:  (47, 12)
# filename:  deezer_MSD/TRBAUVN128F932FEF8.h5
# timbre.shape:  (710, 12)
# timbre_mean.shape:  (48, 12)
# timbre_var.shape:  (48, 12)
# filename:  deezer_MSD/TRACTUH128F92C93A3.h5
# timbre.shape:  (645, 12)
# timbre_mean.shape:  (49, 12)
# timbre_var.shape:  (49, 12)
# filename:  deezer_MSD/TRAWBOE128F92F2F46.h5
# timbre.shape:  (943, 12)
# timbre_mean.shape:  (50, 12)
# timbre_var.shape:  (50, 12)
# filename:  deezer_MSD/TRAQACB128F4263F7B.h5
# timbre.shape:  (625, 12)
# timbre_mean.shape:  (51, 12)
# timbre_var.shape:  (51, 12)
# filename:  deezer_MSD/TRAYWLI128F9300223.h5
# timbre.shape:  (869, 12)
# timbre_mean.shape:  (52, 12)
# timbre_var.shape:  (52, 12)
# filename:  deezer_MSD/TRBHQHN128F148A1B3.h5
# timbre.shape:  (894, 12)
# timbre_mean.shape:  (53, 12)
# timbre_var.shape:  (53, 12)
# filename:  deezer_MSD/TRAADQX128F422B4CF.h5
# timbre.shape:  (979, 12)
# timbre_mean.shape:  (54, 12)
# timbre_var.shape:  (54, 12)
# filename:  deezer_MSD/TRBFIAK128E07823AA.h5
# timbre.shape:  (472, 12)
# timbre_mean.shape:  (55, 12)
# timbre_var.shape:  (55, 12)
# filename:  deezer_MSD/TRABAFJ128F42AF24E.h5
# timbre.shape:  (733, 12)
# timbre_mean.shape:  (56, 12)
# timbre_var.shape:  (56, 12)
# filename:  deezer_MSD/TRAONNA128F4268CCA.h5
# timbre.shape:  (1138, 12)
# timbre_mean.shape:  (57, 12)
# timbre_var.shape:  (57, 12)
# filename:  deezer_MSD/TRAWSXV128F4273E35.h5
# timbre.shape:  (1347, 12)
# timbre_mean.shape:  (58, 12)
# timbre_var.shape:  (58, 12)
# filename:  deezer_MSD/TRBDMDS128F930B8F1.h5
# timbre.shape:  (676, 12)
# timbre_mean.shape:  (59, 12)
# timbre_var.shape:  (59, 12)
# filename:  deezer_MSD/TRAXDBM128E0785BD8.h5
# timbre.shape:  (868, 12)
# timbre_mean.shape:  (60, 12)
# timbre_var.shape:  (60, 12)
# filename:  deezer_MSD/TRAOUTM128F4267580.h5
# timbre.shape:  (1015, 12)
# timbre_mean.shape:  (61, 12)
# timbre_var.shape:  (61, 12)
# filename:  deezer_MSD/TRAYQLF128F933B4EF.h5
# timbre.shape:  (983, 12)
# timbre_mean.shape:  (62, 12)
# timbre_var.shape:  (62, 12)
# filename:  deezer_MSD/TRAFAJC128E078888B.h5
# timbre.shape:  (241, 12)
# timbre_mean.shape:  (63, 12)
# timbre_var.shape:  (63, 12)
# filename:  deezer_MSD/TRAAGPJ128F428CD1B.h5
# timbre.shape:  (1036, 12)
# timbre_mean.shape:  (64, 12)
# timbre_var.shape:  (64, 12)
# filename:  deezer_MSD/TRALJVQ128F428C764.h5
# timbre.shape:  (814, 12)
# timbre_mean.shape:  (65, 12)
# timbre_var.shape:  (65, 12)
# filename:  deezer_MSD/TRACISV12903D13877.h5
# timbre.shape:  (728, 12)
# timbre_mean.shape:  (66, 12)
# timbre_var.shape:  (66, 12)
# filename:  deezer_MSD/TRAVMFC128F428CDE0.h5
# timbre.shape:  (1052, 12)
# timbre_mean.shape:  (67, 12)
# timbre_var.shape:  (67, 12)
# filename:  deezer_MSD/TRAFWEV128F428D391.h5
# timbre.shape:  (840, 12)
# timbre_mean.shape:  (68, 12)
# timbre_var.shape:  (68, 12)
# filename:  deezer_MSD/TRAMBHU128F425A620.h5
# timbre.shape:  (887, 12)
# timbre_mean.shape:  (69, 12)
# timbre_var.shape:  (69, 12)
# filename:  deezer_MSD/TRARAEG128F42647B2.h5
# timbre.shape:  (1038, 12)
# timbre_mean.shape:  (70, 12)
# timbre_var.shape:  (70, 12)
# filename:  deezer_MSD/TRBCIQL128F427C0AD.h5
# timbre.shape:  (1369, 12)
# timbre_mean.shape:  (71, 12)
# timbre_var.shape:  (71, 12)
# filename:  deezer_MSD/TRAQGMY128F425A2F5.h5
# timbre.shape:  (1029, 12)
# timbre_mean.shape:  (72, 12)
# timbre_var.shape:  (72, 12)
# filename:  deezer_MSD/TRARFOC128F92ED401.h5
# timbre.shape:  (1519, 12)
# timbre_mean.shape:  (73, 12)
# timbre_var.shape:  (73, 12)
# filename:  deezer_MSD/TRBHZYO128E07862BE.h5
# timbre.shape:  (1088, 12)
# timbre_mean.shape:  (74, 12)
# timbre_var.shape:  (74, 12)
# filename:  deezer_MSD/TRAANLO128F422AE37.h5
# timbre.shape:  (835, 12)
# timbre_mean.shape:  (75, 12)
# timbre_var.shape:  (75, 12)
# filename:  deezer_MSD/TRBAMHJ128F9302A08.h5
# timbre.shape:  (840, 12)
# timbre_mean.shape:  (76, 12)
# timbre_var.shape:  (76, 12)
# filename:  deezer_MSD/TRBBMQN128EF35F995.h5
# timbre.shape:  (609, 12)
# timbre_mean.shape:  (77, 12)
# timbre_var.shape:  (77, 12)
# filename:  deezer_MSD/TRACEDP128F145F7BB.h5
# timbre.shape:  (1000, 12)
# timbre_mean.shape:  (78, 12)
# timbre_var.shape:  (78, 12)
# filename:  deezer_MSD/TRBHCXR128F92E7D0E.h5
# timbre.shape:  (791, 12)
# timbre_mean.shape:  (79, 12)
# timbre_var.shape:  (79, 12)
# filename:  deezer_MSD/TRAMKRX128EF3686A4.h5
# timbre.shape:  (804, 12)
# timbre_mean.shape:  (80, 12)
# timbre_var.shape:  (80, 12)
# filename:  deezer_MSD/TRADFII128F931FC9F.h5
# timbre.shape:  (1333, 12)
# timbre_mean.shape:  (81, 12)
# timbre_var.shape:  (81, 12)
# filename:  deezer_MSD/TRAPFXX128E0785EBA.h5
# timbre.shape:  (740, 12)
# timbre_mean.shape:  (82, 12)
# timbre_var.shape:  (82, 12)
# filename:  deezer_MSD/TRANLJA128F42A5379.h5
# timbre.shape:  (495, 12)
# timbre_mean.shape:  (83, 12)
# timbre_var.shape:  (83, 12)
# filename:  deezer_MSD/TRALIEV128F92DE23C.h5
# timbre.shape:  (686, 12)
# timbre_mean.shape:  (84, 12)
# timbre_var.shape:  (84, 12)
# filename:  deezer_MSD/TRAVWIP128E078FA3D.h5
# timbre.shape:  (1481, 12)
# timbre_mean.shape:  (85, 12)
# timbre_var.shape:  (85, 12)
# filename:  deezer_MSD/TRBDIOP128EF35F99C.h5
# timbre.shape:  (1078, 12)
# timbre_mean.shape:  (86, 12)
# timbre_var.shape:  (86, 12)
# filename:  deezer_MSD/TRAUFCU128F42882B7.h5
# timbre.shape:  (467, 12)
# timbre_mean.shape:  (87, 12)
# timbre_var.shape:  (87, 12)
# filename:  deezer_MSD/TRAISYO128E07888A6.h5
# timbre.shape:  (769, 12)
# timbre_mean.shape:  (88, 12)
# timbre_var.shape:  (88, 12)
# filename:  deezer_MSD/TRAWFGF128E0792FE0.h5
# timbre.shape:  (951, 12)
# timbre_mean.shape:  (89, 12)
# timbre_var.shape:  (89, 12)
# filename:  deezer_MSD/TRAUURC128E078EC6E.h5
# timbre.shape:  (1288, 12)
# timbre_mean.shape:  (90, 12)
# timbre_var.shape:  (90, 12)
# filename:  deezer_MSD/TRBFUMI128F42B5731.h5
# timbre.shape:  (546, 12)
# timbre_mean.shape:  (91, 12)
# timbre_var.shape:  (91, 12)
# filename:  deezer_MSD/TRBGGOS128F9307FC5.h5
# timbre.shape:  (1098, 12)
# timbre_mean.shape:  (92, 12)
# timbre_var.shape:  (92, 12)
# filename:  deezer_MSD/TRAXNOE128F149158A.h5
# timbre.shape:  (1059, 12)
# timbre_mean.shape:  (93, 12)
# timbre_var.shape:  (93, 12)
# filename:  deezer_MSD/TRAESWB128F149CB2C.h5
# timbre.shape:  (1282, 12)
# timbre_mean.shape:  (94, 12)
# timbre_var.shape:  (94, 12)
# filename:  deezer_MSD/TRAZYYE128F1456A0E.h5
# timbre.shape:  (488, 12)
# timbre_mean.shape:  (95, 12)
# timbre_var.shape:  (95, 12)
# filename:  deezer_MSD/TRAWCQE128F14676AC.h5
# timbre.shape:  (1063, 12)
# timbre_mean.shape:  (96, 12)
# timbre_var.shape:  (96, 12)
# filename:  deezer_MSD/TRAMMAF128F93051B0.h5
# timbre.shape:  (744, 12)
# timbre_mean.shape:  (97, 12)
# timbre_var.shape:  (97, 12)
# filename:  deezer_MSD/TRAYJOF128F92F9EEA.h5
# timbre.shape:  (500, 12)
# timbre_mean.shape:  (98, 12)
# timbre_var.shape:  (98, 12)
# filename:  deezer_MSD/TRAIYDL128E0791583.h5
# timbre.shape:  (954, 12)
# timbre_mean.shape:  (99, 12)
# timbre_var.shape:  (99, 12)
# filename:  deezer_MSD/TRANRFB128F1481F1E.h5
# timbre.shape:  (1393, 12)
# timbre_mean.shape:  (100, 12)
# timbre_var.shape:  (100, 12)
# filename:  deezer_MSD/TRBCYOI128F1455566.h5
# timbre.shape:  (864, 12)
# timbre_mean.shape:  (101, 12)
# timbre_var.shape:  (101, 12)
# filename:  deezer_MSD/TRAYSMW128F1468307.h5
# timbre.shape:  (826, 12)
# timbre_mean.shape:  (102, 12)
# timbre_var.shape:  (102, 12)
# filename:  deezer_MSD/TRAUONA128F4255A38.h5
# timbre.shape:  (658, 12)
# timbre_mean.shape:  (103, 12)
# timbre_var.shape:  (103, 12)
# filename:  deezer_MSD/TRBBMPH128F1469775.h5
# timbre.shape:  (762, 12)
# timbre_mean.shape:  (104, 12)
# timbre_var.shape:  (104, 12)
# filename:  deezer_MSD/TRAXMAK128E07822CB.h5
# timbre.shape:  (715, 12)
# timbre_mean.shape:  (105, 12)
# timbre_var.shape:  (105, 12)
# filename:  deezer_MSD/TRADVSU128E0786371.h5
# timbre.shape:  (784, 12)
# timbre_mean.shape:  (106, 12)
# timbre_var.shape:  (106, 12)
# filename:  deezer_MSD/TRABUCZ128F424163A.h5
# timbre.shape:  (550, 12)
# timbre_mean.shape:  (107, 12)
# timbre_var.shape:  (107, 12)
# filename:  deezer_MSD/TRAZCOX128F42B6555.h5
# timbre.shape:  (537, 12)
# timbre_mean.shape:  (108, 12)
# timbre_var.shape:  (108, 12)
# filename:  deezer_MSD/TRAIPST128F9302AE9.h5
# timbre.shape:  (1118, 12)
# timbre_mean.shape:  (109, 12)
# timbre_var.shape:  (109, 12)
# filename:  deezer_MSD/TRAAIHL128F92E6DDA.h5
# timbre.shape:  (1023, 12)
# timbre_mean.shape:  (110, 12)
# timbre_var.shape:  (110, 12)
# filename:  deezer_MSD/TRAEVHU128F92D9EA0.h5
# timbre.shape:  (680, 12)
# timbre_mean.shape:  (111, 12)
# timbre_var.shape:  (111, 12)
# filename:  deezer_MSD/TRBBXSE128F42798F6.h5
# timbre.shape:  (1251, 12)
# timbre_mean.shape:  (112, 12)
# timbre_var.shape:  (112, 12)
# filename:  deezer_MSD/TRBGRIP128F147FCA6.h5
# timbre.shape:  (984, 12)
# timbre_mean.shape:  (113, 12)
# timbre_var.shape:  (113, 12)
# filename:  deezer_MSD/TRASRXK128F9311176.h5
# timbre.shape:  (598, 12)
# timbre_mean.shape:  (114, 12)
# timbre_var.shape:  (114, 12)
# filename:  deezer_MSD/TRALEPN128F9311179.h5
# timbre.shape:  (514, 12)
# timbre_mean.shape:  (115, 12)
# timbre_var.shape:  (115, 12)
# filename:  deezer_MSD/TRAMGPM128F9311196.h5
# timbre.shape:  (717, 12)
# timbre_mean.shape:  (116, 12)
# timbre_var.shape:  (116, 12)
# filename:  deezer_MSD/TRANHYE128F92DE232.h5
# timbre.shape:  (698, 12)
# timbre_mean.shape:  (117, 12)
# timbre_var.shape:  (117, 12)
# filename:  deezer_MSD/TRAJPIQ128F14819A8.h5
# timbre.shape:  (1144, 12)
# timbre_mean.shape:  (118, 12)
# timbre_var.shape:  (118, 12)
# filename:  deezer_MSD/TRAWOHD128F148D176.h5
# timbre.shape:  (664, 12)
# timbre_mean.shape:  (119, 12)
# timbre_var.shape:  (119, 12)
# filename:  deezer_MSD/TRABFKN12903CAF61B.h5
# timbre.shape:  (520, 12)
# timbre_mean.shape:  (120, 12)
# timbre_var.shape:  (120, 12)
# filename:  deezer_MSD/TRAXUQL128F932D6C4.h5
# timbre.shape:  (749, 12)
# timbre_mean.shape:  (121, 12)
# timbre_var.shape:  (121, 12)
# filename:  deezer_MSD/TRARREF128F422FD96.h5
# timbre.shape:  (774, 12)
# timbre_mean.shape:  (122, 12)
# timbre_var.shape:  (122, 12)
# filename:  deezer_MSD/TRASYQQ128F425092B.h5
# timbre.shape:  (1804, 12)
# timbre_mean.shape:  (123, 12)
# timbre_var.shape:  (123, 12)
# filename:  deezer_MSD/TRAUYZG12903CDA4E9.h5
# timbre.shape:  (1001, 12)
# timbre_mean.shape:  (124, 12)
# timbre_var.shape:  (124, 12)
# filename:  deezer_MSD/TRARQSD128F427E2AA.h5
# timbre.shape:  (698, 12)
# timbre_mean.shape:  (125, 12)
# timbre_var.shape:  (125, 12)
# filename:  deezer_MSD/TRAHLDG128F92EB4A9.h5
# timbre.shape:  (1436, 12)
# timbre_mean.shape:  (126, 12)
# timbre_var.shape:  (126, 12)
# filename:  deezer_MSD/TRAGBOR128F92E1064.h5
# timbre.shape:  (1095, 12)
# timbre_mean.shape:  (127, 12)
# timbre_var.shape:  (127, 12)
# filename:  deezer_MSD/TRAAPFQ128F42684DB.h5
# timbre.shape:  (451, 12)
# timbre_mean.shape:  (128, 12)
# timbre_var.shape:  (128, 12)
# filename:  deezer_MSD/TRAMKUA128F92ED3E1.h5
# timbre.shape:  (886, 12)
# timbre_mean.shape:  (129, 12)
# timbre_var.shape:  (129, 12)
# filename:  deezer_MSD/TRAPAZE128F4233355.h5
# timbre.shape:  (407, 12)
# timbre_mean.shape:  (130, 12)
# timbre_var.shape:  (130, 12)
# filename:  deezer_MSD/TRADVGV128F42BCACE.h5
# timbre.shape:  (592, 12)
# timbre_mean.shape:  (131, 12)
# timbre_var.shape:  (131, 12)
# filename:  deezer_MSD/TRAFYGO128F42727E7.h5
# timbre.shape:  (1015, 12)
# timbre_mean.shape:  (132, 12)
# timbre_var.shape:  (132, 12)
# filename:  deezer_MSD/TRBALRR128F429625D.h5
# timbre.shape:  (745, 12)
# timbre_mean.shape:  (133, 12)
# timbre_var.shape:  (133, 12)
# filename:  deezer_MSD/TRAMMDM128F425EAA9.h5
# timbre.shape:  (1219, 12)
# timbre_mean.shape:  (134, 12)
# timbre_var.shape:  (134, 12)
# filename:  deezer_MSD/TRAWSJK128F42767F2.h5
# timbre.shape:  (1076, 12)
# timbre_mean.shape:  (135, 12)
# timbre_var.shape:  (135, 12)
# filename:  deezer_MSD/TRBGZKO128F92DB016.h5
# timbre.shape:  (613, 12)
# timbre_mean.shape:  (136, 12)
# timbre_var.shape:  (136, 12)
# filename:  deezer_MSD/TRATOAJ128F422F6A7.h5
# timbre.shape:  (422, 12)
# timbre_mean.shape:  (137, 12)
# timbre_var.shape:  (137, 12)
# filename:  deezer_MSD/TRAWFVE128F42912CA.h5
# timbre.shape:  (773, 12)
# timbre_mean.shape:  (138, 12)
# timbre_var.shape:  (138, 12)
# filename:  deezer_MSD/TRBEBWG128F93214A4.h5
# timbre.shape:  (765, 12)
# timbre_mean.shape:  (139, 12)
# timbre_var.shape:  (139, 12)
# filename:  deezer_MSD/TRAAGPH128F4273C8D.h5
# timbre.shape:  (324, 12)
# timbre_mean.shape:  (140, 12)
# timbre_var.shape:  (140, 12)
# filename:  deezer_MSD/TRBDXIM128F427ABDA.h5
# timbre.shape:  (984, 12)
# timbre_mean.shape:  (141, 12)
# timbre_var.shape:  (141, 12)
# filename:  deezer_MSD/TRANQLL128F92F5263.h5
# timbre.shape:  (969, 12)
# timbre_mean.shape:  (142, 12)
# timbre_var.shape:  (142, 12)
# filename:  deezer_MSD/TRAASKQ128F4265E04.h5
# timbre.shape:  (539, 12)
# timbre_mean.shape:  (143, 12)
# timbre_var.shape:  (143, 12)
# filename:  deezer_MSD/TRBHLBZ128F9300586.h5
# timbre.shape:  (601, 12)
# timbre_mean.shape:  (144, 12)
# timbre_var.shape:  (144, 12)
# filename:  deezer_MSD/TRADAOM128F4263A78.h5
# timbre.shape:  (1291, 12)
# timbre_mean.shape:  (145, 12)
# timbre_var.shape:  (145, 12)
# filename:  deezer_MSD/TRAPPUN128F429400B.h5
# timbre.shape:  (749, 12)
# timbre_mean.shape:  (146, 12)
# timbre_var.shape:  (146, 12)
# filename:  deezer_MSD/TRBCGRI128F93355E9.h5
# timbre.shape:  (845, 12)
# timbre_mean.shape:  (147, 12)
# timbre_var.shape:  (147, 12)
# filename:  deezer_MSD/TRACUEE128F427EA05.h5
# timbre.shape:  (502, 12)
# timbre_mean.shape:  (148, 12)
# timbre_var.shape:  (148, 12)
# filename:  deezer_MSD/TRANCFS12903C9B61B.h5
# timbre.shape:  (979, 12)
# timbre_mean.shape:  (149, 12)
# timbre_var.shape:  (149, 12)
# filename:  deezer_MSD/TRAJFFF128F429874A.h5
# timbre.shape:  (727, 12)
# timbre_mean.shape:  (150, 12)
# timbre_var.shape:  (150, 12)
# filename:  deezer_MSD/TRADZXK128F429DB92.h5
# timbre.shape:  (420, 12)
# timbre_mean.shape:  (151, 12)
# timbre_var.shape:  (151, 12)
# filename:  deezer_MSD/TRALPXC128E07819A8.h5
# timbre.shape:  (607, 12)
# timbre_mean.shape:  (152, 12)
# timbre_var.shape:  (152, 12)
# filename:  deezer_MSD/TRATKVY128EF35F97A.h5
# timbre.shape:  (734, 12)
# timbre_mean.shape:  (153, 12)
# timbre_var.shape:  (153, 12)
# filename:  deezer_MSD/TRAQAIW12903C9B61E.h5
# timbre.shape:  (857, 12)
# timbre_mean.shape:  (154, 12)
# timbre_var.shape:  (154, 12)
# filename:  deezer_MSD/TRAYLRS128F427FE81.h5
# timbre.shape:  (676, 12)
# timbre_mean.shape:  (155, 12)
# timbre_var.shape:  (155, 12)
# filename:  deezer_MSD/TRAUSHD128E0795347.h5
# timbre.shape:  (669, 12)
# timbre_mean.shape:  (156, 12)
# timbre_var.shape:  (156, 12)
# filename:  deezer_MSD/TRBEBYV128F14A0B65.h5
# timbre.shape:  (1056, 12)
# timbre_mean.shape:  (157, 12)
# timbre_var.shape:  (157, 12)
# filename:  deezer_MSD/TRAUVSF128F14A0B6F.h5
# timbre.shape:  (1594, 12)
# timbre_mean.shape:  (158, 12)
# timbre_var.shape:  (158, 12)
# filename:  deezer_MSD/TRASZUN128F148B165.h5
# timbre.shape:  (658, 12)
# timbre_mean.shape:  (159, 12)
# timbre_var.shape:  (159, 12)
# filename:  deezer_MSD/TRBDDQF12903CB309A.h5
# timbre.shape:  (680, 12)
# timbre_mean.shape:  (160, 12)
# timbre_var.shape:  (160, 12)
# filename:  deezer_MSD/TRBEYJR128F4292651.h5
# timbre.shape:  (950, 12)
# timbre_mean.shape:  (161, 12)
# timbre_var.shape:  (161, 12)
# filename:  deezer_MSD/TRAZWGV128F425DA7C.h5
# timbre.shape:  (939, 12)
# timbre_mean.shape:  (162, 12)
# timbre_var.shape:  (162, 12)
# filename:  deezer_MSD/TRADQAR128F92ED3DC.h5
# timbre.shape:  (870, 12)
# timbre_mean.shape:  (163, 12)
# timbre_var.shape:  (163, 12)
# filename:  deezer_MSD/TRBIFGK128F92F23A2.h5
# timbre.shape:  (658, 12)
# timbre_mean.shape:  (164, 12)
# timbre_var.shape:  (164, 12)
# filename:  deezer_MSD/TRAKTWZ128EF35E206.h5
# timbre.shape:  (999, 12)
# timbre_mean.shape:  (165, 12)
# timbre_var.shape:  (165, 12)
# filename:  deezer_MSD/TRBBEGG128F9314BAA.h5
# timbre.shape:  (885, 12)
# timbre_mean.shape:  (166, 12)
# timbre_var.shape:  (166, 12)
# filename:  deezer_MSD/TRAWULX128F4291255.h5
# timbre.shape:  (987, 12)
# timbre_mean.shape:  (167, 12)
# timbre_var.shape:  (167, 12)
# filename:  deezer_MSD/TRARODV128F1460DBC.h5
# timbre.shape:  (669, 12)
# timbre_mean.shape:  (168, 12)
# timbre_var.shape:  (168, 12)
# filename:  deezer_MSD/TRAWWQM128F148C796.h5
# timbre.shape:  (814, 12)
# timbre_mean.shape:  (169, 12)
# timbre_var.shape:  (169, 12)
# filename:  deezer_MSD/TRASWFP128E0789E6C.h5
# timbre.shape:  (501, 12)
# timbre_mean.shape:  (170, 12)
# timbre_var.shape:  (170, 12)
# filename:  deezer_MSD/TRAFAIB128F426E636.h5
# timbre.shape:  (604, 12)
# timbre_mean.shape:  (171, 12)
# timbre_var.shape:  (171, 12)
# filename:  deezer_MSD/TRAIZQI128F42A51F9.h5
# timbre.shape:  (967, 12)
# timbre_mean.shape:  (172, 12)
# timbre_var.shape:  (172, 12)
# filename:  deezer_MSD/TRARMUI128F147162F.h5
# timbre.shape:  (590, 12)
# timbre_mean.shape:  (173, 12)
# timbre_var.shape:  (173, 12)
# filename:  deezer_MSD/TRBIJMU12903CF892B.h5
# timbre.shape:  (1132, 12)
# timbre_mean.shape:  (174, 12)
# timbre_var.shape:  (174, 12)
# filename:  deezer_MSD/TRANLHL12903CF88E5.h5
# timbre.shape:  (854, 12)
# timbre_mean.shape:  (175, 12)
# timbre_var.shape:  (175, 12)
# filename:  deezer_MSD/TRBGRXO128F4282115.h5
# timbre.shape:  (885, 12)
# timbre_mean.shape:  (176, 12)
# timbre_var.shape:  (176, 12)
# filename:  deezer_MSD/TRALQZK128F429802D.h5
# timbre.shape:  (554, 12)
# timbre_mean.shape:  (177, 12)
# timbre_var.shape:  (177, 12)
# filename:  deezer_MSD/TRBIBGN128F42ADC66.h5
# timbre.shape:  (720, 12)
# timbre_mean.shape:  (178, 12)
# timbre_var.shape:  (178, 12)
# filename:  deezer_MSD/TRAVMRI128F4259E76.h5
# timbre.shape:  (1369, 12)
# timbre_mean.shape:  (179, 12)
# timbre_var.shape:  (179, 12)
# filename:  deezer_MSD/TRBDWRY128F427991E.h5
# timbre.shape:  (1609, 12)
# timbre_mean.shape:  (180, 12)
# timbre_var.shape:  (180, 12)
# filename:  deezer_MSD/TRAFOKY128F4276D91.h5
# timbre.shape:  (542, 12)
# timbre_mean.shape:  (181, 12)
# timbre_var.shape:  (181, 12)
# filename:  deezer_MSD/TRADXMA128F4276D94.h5
# timbre.shape:  (657, 12)
# timbre_mean.shape:  (182, 12)
# timbre_var.shape:  (182, 12)
# filename:  deezer_MSD/TRBBQFV128F4252EFF.h5
# timbre.shape:  (667, 12)
# timbre_mean.shape:  (183, 12)
# timbre_var.shape:  (183, 12)
# filename:  deezer_MSD/TRBEAMO128F425B75F.h5
# timbre.shape:  (656, 12)
# timbre_mean.shape:  (184, 12)
# timbre_var.shape:  (184, 12)
# filename:  deezer_MSD/TRACKAP128F425B741.h5
# timbre.shape:  (1158, 12)
# timbre_mean.shape:  (185, 12)
# timbre_var.shape:  (185, 12)
# filename:  deezer_MSD/TRAAGEC128E079252C.h5
# timbre.shape:  (888, 12)
# timbre_mean.shape:  (186, 12)
# timbre_var.shape:  (186, 12)
# filename:  deezer_MSD/TRBABQW128F148C7FB.h5
# timbre.shape:  (1229, 12)
# timbre_mean.shape:  (187, 12)
# timbre_var.shape:  (187, 12)
# filename:  deezer_MSD/TRAEZLQ128F427F954.h5
# timbre.shape:  (710, 12)
# timbre_mean.shape:  (188, 12)
# timbre_var.shape:  (188, 12)
# filename:  deezer_MSD/TRAECVW128E078884D.h5
# timbre.shape:  (435, 12)
# timbre_mean.shape:  (189, 12)
# timbre_var.shape:  (189, 12)
# filename:  deezer_MSD/TRAWRKT128E0788857.h5
# timbre.shape:  (780, 12)
# timbre_mean.shape:  (190, 12)
# timbre_var.shape:  (190, 12)
# filename:  deezer_MSD/TRACNAS128F14567C6.h5
# timbre.shape:  (785, 12)
# timbre_mean.shape:  (191, 12)
# timbre_var.shape:  (191, 12)
# filename:  deezer_MSD/TRAWTGS128F14569A8.h5
# timbre.shape:  (481, 12)
# timbre_mean.shape:  (192, 12)
# timbre_var.shape:  (192, 12)
# filename:  deezer_MSD/TRAKQXJ128F147A028.h5
# timbre.shape:  (515, 12)
# timbre_mean.shape:  (193, 12)
# timbre_var.shape:  (193, 12)
# filename:  deezer_MSD/TRBBQPP128F92EE611.h5
# timbre.shape:  (1247, 12)
# timbre_mean.shape:  (194, 12)
# timbre_var.shape:  (194, 12)
# filename:  deezer_MSD/TRANCJG128F14528B4.h5
# timbre.shape:  (600, 12)
# timbre_mean.shape:  (195, 12)
# timbre_var.shape:  (195, 12)
# filename:  deezer_MSD/TRBESBZ12903CA0A95.h5
# timbre.shape:  (711, 12)
# timbre_mean.shape:  (196, 12)
# timbre_var.shape:  (196, 12)
# filename:  deezer_MSD/TRAMRFE128F4267DF3.h5
# timbre.shape:  (635, 12)
# timbre_mean.shape:  (197, 12)
# timbre_var.shape:  (197, 12)
# filename:  deezer_MSD/TRAMESI128F93509F7.h5
# timbre.shape:  (625, 12)
# timbre_mean.shape:  (198, 12)
# timbre_var.shape:  (198, 12)
# filename:  deezer_MSD/TRALBIA128F4272082.h5
# timbre.shape:  (759, 12)
# timbre_mean.shape:  (199, 12)
# timbre_var.shape:  (199, 12)
# filename:  deezer_MSD/TRAMCJI128F93335AF.h5
# timbre.shape:  (984, 12)
# timbre_mean.shape:  (200, 12)
# timbre_var.shape:  (200, 12)
# filename:  deezer_MSD/TRAVMXD12903CBBD0B.h5
# timbre.shape:  (1482, 12)
# timbre_mean.shape:  (201, 12)
# timbre_var.shape:  (201, 12)
# filename:  deezer_MSD/TRAEUIW12903D018F0.h5
# timbre.shape:  (693, 12)
# timbre_mean.shape:  (202, 12)
# timbre_var.shape:  (202, 12)
# filename:  deezer_MSD/TRARANL128F1478789.h5
# timbre.shape:  (596, 12)
# timbre_mean.shape:  (203, 12)
# timbre_var.shape:  (203, 12)
# filename:  deezer_MSD/TRAPEIN128E078892E.h5
# timbre.shape:  (424, 12)
# timbre_mean.shape:  (204, 12)
# timbre_var.shape:  (204, 12)
# filename:  deezer_MSD/TRASWIV128E0788A84.h5
# timbre.shape:  (426, 12)
# timbre_mean.shape:  (205, 12)
# timbre_var.shape:  (205, 12)
# filename:  deezer_MSD/TRAERPT128F931103E.h5
# timbre.shape:  (527, 12)
# timbre_mean.shape:  (206, 12)
# timbre_var.shape:  (206, 12)
# filename:  deezer_MSD/TRALTKQ128F932DA67.h5
# timbre.shape:  (580, 12)
# timbre_mean.shape:  (207, 12)
# timbre_var.shape:  (207, 12)
# filename:  deezer_MSD/TRAQQHJ128F9345DC3.h5
# timbre.shape:  (567, 12)
# timbre_mean.shape:  (208, 12)
# timbre_var.shape:  (208, 12)
# filename:  deezer_MSD/TRBBCUA128E078FA50.h5
# timbre.shape:  (752, 12)
# timbre_mean.shape:  (209, 12)
# timbre_var.shape:  (209, 12)
# filename:  deezer_MSD/TRBCUBV128F145F7E9.h5
# timbre.shape:  (818, 12)
# timbre_mean.shape:  (210, 12)
# timbre_var.shape:  (210, 12)
# filename:  deezer_MSD/TRBIGRY128F42597B3.h5
# timbre.shape:  (506, 12)
# timbre_mean.shape:  (211, 12)
# timbre_var.shape:  (211, 12)
# filename:  deezer_MSD/TRBCNGI128F42597B4.h5
# timbre.shape:  (1140, 12)
# timbre_mean.shape:  (212, 12)
# timbre_var.shape:  (212, 12)
# filename:  deezer_MSD/TRAZDTT128F9346306.h5
# timbre.shape:  (435, 12)
# timbre_mean.shape:  (213, 12)
# timbre_var.shape:  (213, 12)
# filename:  deezer_MSD/TRARVEY128F9300AC3.h5
# timbre.shape:  (821, 12)
# timbre_mean.shape:  (214, 12)
# timbre_var.shape:  (214, 12)
# filename:  deezer_MSD/TRASNOT128E0791785.h5
# timbre.shape:  (656, 12)
# timbre_mean.shape:  (215, 12)
# timbre_var.shape:  (215, 12)
# filename:  deezer_MSD/TRAPHZT128F147A02B.h5
# timbre.shape:  (952, 12)
# timbre_mean.shape:  (216, 12)
# timbre_var.shape:  (216, 12)
# filename:  deezer_MSD/TRALIHL128E0791C9A.h5
# timbre.shape:  (1145, 12)
# timbre_mean.shape:  (217, 12)
# timbre_var.shape:  (217, 12)
# filename:  deezer_MSD/TRAPGKY128F42972A9.h5
# timbre.shape:  (618, 12)
# timbre_mean.shape:  (218, 12)
# timbre_var.shape:  (218, 12)
# filename:  deezer_MSD/TRAIELD128F92DC682.h5
# timbre.shape:  (687, 12)
# timbre_mean.shape:  (219, 12)
# timbre_var.shape:  (219, 12)
# filename:  deezer_MSD/TRAHZMM128E07838FF.h5
# timbre.shape:  (689, 12)
# timbre_mean.shape:  (220, 12)
# timbre_var.shape:  (220, 12)
# filename:  deezer_MSD/TRAFRYJ128F92E638B.h5
# timbre.shape:  (1965, 12)
# timbre_mean.shape:  (221, 12)
# timbre_var.shape:  (221, 12)
# filename:  deezer_MSD/TRBCANP128F92FA6B9.h5
# timbre.shape:  (779, 12)
# timbre_mean.shape:  (222, 12)
# timbre_var.shape:  (222, 12)
# filename:  deezer_MSD/TRBAXDP12903CD1922.h5
# timbre.shape:  (567, 12)
# timbre_mean.shape:  (223, 12)
# timbre_var.shape:  (223, 12)
# filename:  deezer_MSD/TRAAEEH128E0795DFE.h5
# timbre.shape:  (1011, 12)
# timbre_mean.shape:  (224, 12)
# timbre_var.shape:  (224, 12)

# %% [markdown]
# ### Linear Regression using means and vars of timbre, chroma, and loudmax

# %%
from sklearn.linear_model import LinearRegression
X = np.hstack((timbre_mean,timbre_var,chroma_mean,chroma_var, loudmax_mean, loudmax_var))
y = data['valence'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
y_pred = reg.predict(X)

from sklearn.metrics import mean_squared_error, r2_score
print('Coefficient of determination: {:.2f}'.format(r2_score(y, y_pred)))
print('Mean squared error: {:.2f}'.format(mean_squared_error(y, y_pred)))
# Out:
# Coefficient of determination: 0.30
# Mean squared error: 0.78

# %% [markdown]
# # Q1. Load beat-aligned MSD features, find the best linear model using those features, and report its R squared and mean squared error.

# %% [markdown]
# You've loaded MSD timbre, chroma, and loudmax features and calculated their means and variances. And then, you also find the best linear model using sklearn.linear_model.LinearRegression and reported the R squared score (r2_score) and mean squared error (mean_squared_error).
#
# As we learned last week, we use not only simple mean and variance of features but also variance and mean of the mean of means as well. In Q1-1, you will use the baf.get_btFEATURENAME(filename) function in beat_aligned_feats.py to get the mean of a feature per each beat. Please calculate the following values and use them as features to linear regression in addition to the means and variances of timbre, chroma, and loudmax features.
#
# - timbre_mean_mean
# - timbre_mean_var
# - chroma_mean_mean
# - chroma_mean_var
# - loudmax_mean_mean
# - loudmax_mean_var
#
# Deliverable: Report R squared scores and mean squared error of the best linear model.

# %% [markdown]
# ### Q1-1. Load beat-aligned MSD timbre, chroma, and loudmax features (1pt)

# %% [markdown]
# As we learned last week, we use not only simple mean and variance of features but also variance and mean of the mean of means as well. In Q1-1, you will use the baf.get_btFEATURENAME(filename) function in beat_aligned_feats.py to get the mean of a feature per each beat. Please calculate the following values and use them as features to linear regression in addition to the means and variances of timbre, chroma, and loudmax features.
# - timbre_mean_mean
# - timbre_mean_var
# - chroma_mean_mean
# - chroma_mean_var
# - loudmax_mean_mean
# - loudmax_mean_var

# %%
## This code shows you how to use beat_aligned_feats.get_btFEATIRE function
## bttimbre is a sort of the mean of timbre per each beat
## That explains the smaller rows of bttimbre
import hdf5_getters
import beat_aligned_feats as baf

filename = 'deezer_MSD/TRAPEIN128E078892E.h5'

timbre = hdf5_getters.get_segments_timbre(h5)
print("timbre.shape: ",timbre.shape)

bttimbre = baf.get_bttimbre(filename)
bttimbre = np.transpose(bttimbre)
print("bttimbre.shape: ",bttimbre.shape)
# Out:
# timbre.shape:  (1011, 12)
# bttimbre.shape:  (270, 12)

# %%
import csv
import hdf5_getters
import beat_aligned_feats as baf

songreader = csv.DictReader(open('moodmsdfeatures.csv'))

timbre_mean_mean = np.empty((0,12), dtype=float)
timbre_mean_var = np.empty((0,12), dtype=float)
chroma_mean_mean = np.empty((0,12), dtype=float)
chroma_mean_var = np.empty((0,12), dtype=float)
loudmax_mean_mean = np.empty((0,1), dtype=float)
loudmax_mean_var = np.empty((0,1), dtype=float)

for song in songreader:
    trid = song['MSD_track_id']
    filename = 'deezer_MSD/' + trid + '.h5'
    
    print(filename)
    #
    #
    #
    # Write codes to caculate timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var
    #
    #
# Out:
# deezer_MSD/TRAYKVH128F42AC993.h5
# bttimbre.shape:  (382, 12)
# timbre_mean_mean.shape:  (1, 12)
# timbre_mean_var.shape:  (1, 12)
# deezer_MSD/TRATCMK12903CABAC8.h5
# bttimbre.shape:  (469, 12)
# timbre_mean_mean.shape:  (2, 12)
# timbre_mean_var.shape:  (2, 12)
# deezer_MSD/TRALJBT128F4266FD8.h5
# bttimbre.shape:  (369, 12)
# timbre_mean_mean.shape:  (3, 12)
# timbre_mean_var.shape:  (3, 12)
# deezer_MSD/TRBGPJP128E078ED20.h5
# bttimbre.shape:  (1238, 12)
# timbre_mean_mean.shape:  (4, 12)
# timbre_mean_var.shape:  (4, 12)
# deezer_MSD/TRAGFPP128E078F34C.h5
# bttimbre.shape:  (701, 12)
# timbre_mean_mean.shape:  (5, 12)
# timbre_mean_var.shape:  (5, 12)
# deezer_MSD/TRAXLPR128F428E466.h5
# bttimbre.shape:  (360, 12)
# timbre_mean_mean.shape:  (6, 12)
# timbre_mean_var.shape:  (6, 12)
# deezer_MSD/TRBBAHD128F428E0FE.h5
# bttimbre.shape:  (613, 12)
# timbre_mean_mean.shape:  (7, 12)
# timbre_mean_var.shape:  (7, 12)
# deezer_MSD/TRBHLDQ128F423EF10.h5
# bttimbre.shape:  (396, 12)
# timbre_mean_mean.shape:  (8, 12)
# timbre_mean_var.shape:  (8, 12)
# deezer_MSD/TRABCUQ128E0783E2B.h5
# bttimbre.shape:  (551, 12)
# timbre_mean_mean.shape:  (9, 12)
# timbre_mean_var.shape:  (9, 12)
# deezer_MSD/TRBCBXZ128F14628C3.h5
# bttimbre.shape:  (361, 12)
# timbre_mean_mean.shape:  (10, 12)
# timbre_mean_var.shape:  (10, 12)
# deezer_MSD/TRBGNCL128F428F56F.h5
# bttimbre.shape:  (594, 12)
# timbre_mean_mean.shape:  (11, 12)
# timbre_mean_var.shape:  (11, 12)
# deezer_MSD/TRAVJHK128E078370B.h5
# bttimbre.shape:  (442, 12)
# timbre_mean_mean.shape:  (12, 12)
# timbre_mean_var.shape:  (12, 12)
# deezer_MSD/TRAKHYP128E0792F07.h5
# bttimbre.shape:  (322, 12)
# timbre_mean_mean.shape:  (13, 12)
# timbre_mean_var.shape:  (13, 12)
# deezer_MSD/TRBCKSF128F932FA70.h5
# bttimbre.shape:  (711, 12)
# timbre_mean_mean.shape:  (14, 12)
# timbre_mean_var.shape:  (14, 12)
# deezer_MSD/TRAMVOM128F42ACB16.h5
# bttimbre.shape:  (588, 12)
# timbre_mean_mean.shape:  (15, 12)
# timbre_mean_var.shape:  (15, 12)
# deezer_MSD/TRAFSIP128F9301AE9.h5
# bttimbre.shape:  (542, 12)
# timbre_mean_mean.shape:  (16, 12)
# timbre_mean_var.shape:  (16, 12)
# deezer_MSD/TRAPMRV128F92F5F4C.h5
# bttimbre.shape:  (509, 12)
# timbre_mean_mean.shape:  (17, 12)
# timbre_mean_var.shape:  (17, 12)
# deezer_MSD/TRANBUW128F933C645.h5
# bttimbre.shape:  (270, 12)
# timbre_mean_mean.shape:  (18, 12)
# timbre_mean_var.shape:  (18, 12)
# deezer_MSD/TRBFURI128F1455498.h5
# bttimbre.shape:  (497, 12)
# timbre_mean_mean.shape:  (19, 12)
# timbre_mean_var.shape:  (19, 12)
# deezer_MSD/TRBFLIP128E07897B4.h5
# bttimbre.shape:  (655, 12)
# timbre_mean_mean.shape:  (20, 12)
# timbre_mean_var.shape:  (20, 12)
# deezer_MSD/TRANAHT128E07895F8.h5
# bttimbre.shape:  (659, 12)
# timbre_mean_mean.shape:  (21, 12)
# timbre_mean_var.shape:  (21, 12)
# deezer_MSD/TRAMRZO12903CA82FB.h5
# bttimbre.shape:  (402, 12)
# timbre_mean_mean.shape:  (22, 12)
# timbre_mean_var.shape:  (22, 12)
# deezer_MSD/TRAQVOG128F9340E58.h5
# bttimbre.shape:  (412, 12)
# timbre_mean_mean.shape:  (23, 12)
# timbre_mean_var.shape:  (23, 12)
# deezer_MSD/TRAUXEU12903CD3CD7.h5
# bttimbre.shape:  (327, 12)
# timbre_mean_mean.shape:  (24, 12)
# timbre_mean_var.shape:  (24, 12)
# deezer_MSD/TRBDUXD128F148328A.h5
# bttimbre.shape:  (731, 12)
# timbre_mean_mean.shape:  (25, 12)
# timbre_mean_var.shape:  (25, 12)
# deezer_MSD/TRANVZT128F42AE134.h5
# bttimbre.shape:  (635, 12)
# timbre_mean_mean.shape:  (26, 12)
# timbre_mean_var.shape:  (26, 12)
# deezer_MSD/TRAACER128F4290F96.h5
# bttimbre.shape:  (572, 12)
# timbre_mean_mean.shape:  (27, 12)
# timbre_mean_var.shape:  (27, 12)
# deezer_MSD/TRAYJHF128F4294CB8.h5
# bttimbre.shape:  (674, 12)
# timbre_mean_mean.shape:  (28, 12)
# timbre_mean_var.shape:  (28, 12)
# deezer_MSD/TRADCHC128F42134B5.h5
# bttimbre.shape:  (447, 12)
# timbre_mean_mean.shape:  (29, 12)
# timbre_mean_var.shape:  (29, 12)
# deezer_MSD/TRBGASN128F427BF8F.h5
# bttimbre.shape:  (350, 12)
# timbre_mean_mean.shape:  (30, 12)
# timbre_mean_var.shape:  (30, 12)
# deezer_MSD/TRBAOTY128F9327A9C.h5
# bttimbre.shape:  (349, 12)
# timbre_mean_mean.shape:  (31, 12)
# timbre_mean_var.shape:  (31, 12)
# deezer_MSD/TRAVGZS128F9338603.h5
# bttimbre.shape:  (214, 12)
# timbre_mean_mean.shape:  (32, 12)
# timbre_mean_var.shape:  (32, 12)
# deezer_MSD/TRAASUZ128F9314950.h5
# bttimbre.shape:  (354, 12)
# timbre_mean_mean.shape:  (33, 12)
# timbre_mean_var.shape:  (33, 12)
# deezer_MSD/TRBAWKB128F931BAEE.h5
# bttimbre.shape:  (569, 12)
# timbre_mean_mean.shape:  (34, 12)
# timbre_mean_var.shape:  (34, 12)
# deezer_MSD/TRADJGI128F148B0F6.h5
# bttimbre.shape:  (472, 12)
# timbre_mean_mean.shape:  (35, 12)
# timbre_mean_var.shape:  (35, 12)
# deezer_MSD/TRBEBEZ128E0792F08.h5
# bttimbre.shape:  (343, 12)
# timbre_mean_mean.shape:  (36, 12)
# timbre_mean_var.shape:  (36, 12)
# deezer_MSD/TRADRJK128E078F041.h5
# bttimbre.shape:  (592, 12)
# timbre_mean_mean.shape:  (37, 12)
# timbre_mean_var.shape:  (37, 12)
# deezer_MSD/TRBFMAS128E078F352.h5
# bttimbre.shape:  (447, 12)
# timbre_mean_mean.shape:  (38, 12)
# timbre_mean_var.shape:  (38, 12)
# deezer_MSD/TRASXZE128F427F156.h5
# bttimbre.shape:  (273, 12)
# timbre_mean_mean.shape:  (39, 12)
# timbre_mean_var.shape:  (39, 12)
# deezer_MSD/TRBCJSZ128E07969B5.h5
# bttimbre.shape:  (606, 12)
# timbre_mean_mean.shape:  (40, 12)
# timbre_mean_var.shape:  (40, 12)
# deezer_MSD/TRAKPHP128F42807B0.h5
# bttimbre.shape:  (785, 12)
# timbre_mean_mean.shape:  (41, 12)
# timbre_mean_var.shape:  (41, 12)
# deezer_MSD/TRAGPAF128EF34542A.h5
# bttimbre.shape:  (269, 12)
# timbre_mean_mean.shape:  (42, 12)
# timbre_mean_var.shape:  (42, 12)
# deezer_MSD/TRAPDOI128F9327982.h5
# bttimbre.shape:  (684, 12)
# timbre_mean_mean.shape:  (43, 12)
# timbre_mean_var.shape:  (43, 12)
# deezer_MSD/TRAPCNK128F427D7B5.h5
# bttimbre.shape:  (355, 12)
# timbre_mean_mean.shape:  (44, 12)
# timbre_mean_var.shape:  (44, 12)
# deezer_MSD/TRAMFAS12903CD7030.h5
# bttimbre.shape:  (1098, 12)
# timbre_mean_mean.shape:  (45, 12)
# timbre_mean_var.shape:  (45, 12)
# deezer_MSD/TRAGFVT128F92ECB5D.h5
# bttimbre.shape:  (778, 12)
# timbre_mean_mean.shape:  (46, 12)
# timbre_mean_var.shape:  (46, 12)
# deezer_MSD/TRAAMES128F42AF068.h5
# bttimbre.shape:  (766, 12)
# timbre_mean_mean.shape:  (47, 12)
# timbre_mean_var.shape:  (47, 12)
# deezer_MSD/TRBAUVN128F932FEF8.h5
# bttimbre.shape:  (333, 12)
# timbre_mean_mean.shape:  (48, 12)
# timbre_mean_var.shape:  (48, 12)
# deezer_MSD/TRACTUH128F92C93A3.h5
# bttimbre.shape:  (267, 12)
# timbre_mean_mean.shape:  (49, 12)
# timbre_mean_var.shape:  (49, 12)
# deezer_MSD/TRAWBOE128F92F2F46.h5
# bttimbre.shape:  (422, 12)
# timbre_mean_mean.shape:  (50, 12)
# timbre_mean_var.shape:  (50, 12)
# deezer_MSD/TRAQACB128F4263F7B.h5
# bttimbre.shape:  (495, 12)
# timbre_mean_mean.shape:  (51, 12)
# timbre_mean_var.shape:  (51, 12)
# deezer_MSD/TRAYWLI128F9300223.h5
# bttimbre.shape:  (778, 12)
# timbre_mean_mean.shape:  (52, 12)
# timbre_mean_var.shape:  (52, 12)
# deezer_MSD/TRBHQHN128F148A1B3.h5
# bttimbre.shape:  (667, 12)
# timbre_mean_mean.shape:  (53, 12)
# timbre_mean_var.shape:  (53, 12)
# deezer_MSD/TRAADQX128F422B4CF.h5
# bttimbre.shape:  (407, 12)
# timbre_mean_mean.shape:  (54, 12)
# timbre_mean_var.shape:  (54, 12)
# deezer_MSD/TRBFIAK128E07823AA.h5
# bttimbre.shape:  (386, 12)
# timbre_mean_mean.shape:  (55, 12)
# timbre_mean_var.shape:  (55, 12)
# deezer_MSD/TRABAFJ128F42AF24E.h5
# bttimbre.shape:  (426, 12)
# timbre_mean_mean.shape:  (56, 12)
# timbre_mean_var.shape:  (56, 12)
# deezer_MSD/TRAONNA128F4268CCA.h5
# bttimbre.shape:  (414, 12)
# timbre_mean_mean.shape:  (57, 12)
# timbre_mean_var.shape:  (57, 12)
# deezer_MSD/TRAWSXV128F4273E35.h5
# bttimbre.shape:  (420, 12)
# timbre_mean_mean.shape:  (58, 12)
# timbre_mean_var.shape:  (58, 12)
# deezer_MSD/TRBDMDS128F930B8F1.h5
# bttimbre.shape:  (467, 12)
# timbre_mean_mean.shape:  (59, 12)
# timbre_mean_var.shape:  (59, 12)
# deezer_MSD/TRAXDBM128E0785BD8.h5
# bttimbre.shape:  (590, 12)
# timbre_mean_mean.shape:  (60, 12)
# timbre_mean_var.shape:  (60, 12)
# deezer_MSD/TRAOUTM128F4267580.h5
# bttimbre.shape:  (500, 12)
# timbre_mean_mean.shape:  (61, 12)
# timbre_mean_var.shape:  (61, 12)
# deezer_MSD/TRAYQLF128F933B4EF.h5
# bttimbre.shape:  (419, 12)
# timbre_mean_mean.shape:  (62, 12)
# timbre_mean_var.shape:  (62, 12)
# deezer_MSD/TRAFAJC128E078888B.h5
# bttimbre.shape:  (212, 12)
# timbre_mean_mean.shape:  (63, 12)
# timbre_mean_var.shape:  (63, 12)
# deezer_MSD/TRAAGPJ128F428CD1B.h5
# bttimbre.shape:  (560, 12)
# timbre_mean_mean.shape:  (64, 12)
# timbre_mean_var.shape:  (64, 12)
# deezer_MSD/TRALJVQ128F428C764.h5
# bttimbre.shape:  (394, 12)
# timbre_mean_mean.shape:  (65, 12)
# timbre_mean_var.shape:  (65, 12)
# deezer_MSD/TRACISV12903D13877.h5
# bttimbre.shape:  (463, 12)
# timbre_mean_mean.shape:  (66, 12)
# timbre_mean_var.shape:  (66, 12)
# deezer_MSD/TRAVMFC128F428CDE0.h5
# bttimbre.shape:  (346, 12)
# timbre_mean_mean.shape:  (67, 12)
# timbre_mean_var.shape:  (67, 12)
# deezer_MSD/TRAFWEV128F428D391.h5
# bttimbre.shape:  (654, 12)
# timbre_mean_mean.shape:  (68, 12)
# timbre_mean_var.shape:  (68, 12)
# deezer_MSD/TRAMBHU128F425A620.h5
# bttimbre.shape:  (477, 12)
# timbre_mean_mean.shape:  (69, 12)
# timbre_mean_var.shape:  (69, 12)
# deezer_MSD/TRARAEG128F42647B2.h5
# bttimbre.shape:  (500, 12)
# timbre_mean_mean.shape:  (70, 12)
# timbre_mean_var.shape:  (70, 12)
# deezer_MSD/TRBCIQL128F427C0AD.h5
# bttimbre.shape:  (488, 12)
# timbre_mean_mean.shape:  (71, 12)
# timbre_mean_var.shape:  (71, 12)
# deezer_MSD/TRAQGMY128F425A2F5.h5
# bttimbre.shape:  (763, 12)
# timbre_mean_mean.shape:  (72, 12)
# timbre_mean_var.shape:  (72, 12)
# deezer_MSD/TRARFOC128F92ED401.h5
# bttimbre.shape:  (842, 12)
# timbre_mean_mean.shape:  (73, 12)
# timbre_mean_var.shape:  (73, 12)
# deezer_MSD/TRBHZYO128E07862BE.h5
# bttimbre.shape:  (366, 12)
# timbre_mean_mean.shape:  (74, 12)
# timbre_mean_var.shape:  (74, 12)
# deezer_MSD/TRAANLO128F422AE37.h5
# bttimbre.shape:  (995, 12)
# timbre_mean_mean.shape:  (75, 12)
# timbre_mean_var.shape:  (75, 12)
# deezer_MSD/TRBAMHJ128F9302A08.h5
# bttimbre.shape:  (448, 12)
# timbre_mean_mean.shape:  (76, 12)
# timbre_mean_var.shape:  (76, 12)
# deezer_MSD/TRBBMQN128EF35F995.h5
# bttimbre.shape:  (437, 12)
# timbre_mean_mean.shape:  (77, 12)
# timbre_mean_var.shape:  (77, 12)
# deezer_MSD/TRACEDP128F145F7BB.h5
# bttimbre.shape:  (607, 12)
# timbre_mean_mean.shape:  (78, 12)
# timbre_mean_var.shape:  (78, 12)
# deezer_MSD/TRBHCXR128F92E7D0E.h5
# bttimbre.shape:  (558, 12)
# timbre_mean_mean.shape:  (79, 12)
# timbre_mean_var.shape:  (79, 12)
# deezer_MSD/TRAMKRX128EF3686A4.h5
# bttimbre.shape:  (583, 12)
# timbre_mean_mean.shape:  (80, 12)
# timbre_mean_var.shape:  (80, 12)
# deezer_MSD/TRADFII128F931FC9F.h5
# bttimbre.shape:  (872, 12)
# timbre_mean_mean.shape:  (81, 12)
# timbre_mean_var.shape:  (81, 12)
# deezer_MSD/TRAPFXX128E0785EBA.h5
# bttimbre.shape:  (391, 12)
# timbre_mean_mean.shape:  (82, 12)
# timbre_mean_var.shape:  (82, 12)
# deezer_MSD/TRANLJA128F42A5379.h5
# bttimbre.shape:  (451, 12)
# timbre_mean_mean.shape:  (83, 12)
# timbre_mean_var.shape:  (83, 12)
# deezer_MSD/TRALIEV128F92DE23C.h5
# bttimbre.shape:  (674, 12)
# timbre_mean_mean.shape:  (84, 12)
# timbre_mean_var.shape:  (84, 12)
# deezer_MSD/TRAVWIP128E078FA3D.h5
# bttimbre.shape:  (520, 12)
# timbre_mean_mean.shape:  (85, 12)
# timbre_mean_var.shape:  (85, 12)
# deezer_MSD/TRBDIOP128EF35F99C.h5
# bttimbre.shape:  (730, 12)
# timbre_mean_mean.shape:  (86, 12)
# timbre_mean_var.shape:  (86, 12)
# deezer_MSD/TRAUFCU128F42882B7.h5
# bttimbre.shape:  (339, 12)
# timbre_mean_mean.shape:  (87, 12)
# timbre_mean_var.shape:  (87, 12)
# deezer_MSD/TRAISYO128E07888A6.h5
# bttimbre.shape:  (526, 12)
# timbre_mean_mean.shape:  (88, 12)
# timbre_mean_var.shape:  (88, 12)
# deezer_MSD/TRAWFGF128E0792FE0.h5
# bttimbre.shape:  (512, 12)
# timbre_mean_mean.shape:  (89, 12)
# timbre_mean_var.shape:  (89, 12)
# deezer_MSD/TRAUURC128E078EC6E.h5
# bttimbre.shape:  (932, 12)
# timbre_mean_mean.shape:  (90, 12)
# timbre_mean_var.shape:  (90, 12)
# deezer_MSD/TRBFUMI128F42B5731.h5
# bttimbre.shape:  (310, 12)
# timbre_mean_mean.shape:  (91, 12)
# timbre_mean_var.shape:  (91, 12)
# deezer_MSD/TRBGGOS128F9307FC5.h5
# bttimbre.shape:  (732, 12)
# timbre_mean_mean.shape:  (92, 12)
# timbre_mean_var.shape:  (92, 12)
# deezer_MSD/TRAXNOE128F149158A.h5
# bttimbre.shape:  (440, 12)
# timbre_mean_mean.shape:  (93, 12)
# timbre_mean_var.shape:  (93, 12)
# deezer_MSD/TRAESWB128F149CB2C.h5
# bttimbre.shape:  (610, 12)
# timbre_mean_mean.shape:  (94, 12)
# timbre_mean_var.shape:  (94, 12)
# deezer_MSD/TRAZYYE128F1456A0E.h5
# bttimbre.shape:  (261, 12)
# timbre_mean_mean.shape:  (95, 12)
# timbre_mean_var.shape:  (95, 12)
# deezer_MSD/TRAWCQE128F14676AC.h5
# bttimbre.shape:  (839, 12)
# timbre_mean_mean.shape:  (96, 12)
# timbre_mean_var.shape:  (96, 12)
# deezer_MSD/TRAMMAF128F93051B0.h5
# bttimbre.shape:  (341, 12)
# timbre_mean_mean.shape:  (97, 12)
# timbre_mean_var.shape:  (97, 12)
# deezer_MSD/TRAYJOF128F92F9EEA.h5
# bttimbre.shape:  (495, 12)
# timbre_mean_mean.shape:  (98, 12)
# timbre_mean_var.shape:  (98, 12)
# deezer_MSD/TRAIYDL128E0791583.h5
# bttimbre.shape:  (335, 12)
# timbre_mean_mean.shape:  (99, 12)
# timbre_mean_var.shape:  (99, 12)
# deezer_MSD/TRANRFB128F1481F1E.h5
# bttimbre.shape:  (702, 12)
# timbre_mean_mean.shape:  (100, 12)
# timbre_mean_var.shape:  (100, 12)
# deezer_MSD/TRBCYOI128F1455566.h5
# bttimbre.shape:  (317, 12)
# timbre_mean_mean.shape:  (101, 12)
# timbre_mean_var.shape:  (101, 12)
# deezer_MSD/TRAYSMW128F1468307.h5
# bttimbre.shape:  (332, 12)
# timbre_mean_mean.shape:  (102, 12)
# timbre_mean_var.shape:  (102, 12)
# deezer_MSD/TRAUONA128F4255A38.h5
# bttimbre.shape:  (224, 12)
# timbre_mean_mean.shape:  (103, 12)
# timbre_mean_var.shape:  (103, 12)
# deezer_MSD/TRBBMPH128F1469775.h5
# bttimbre.shape:  (414, 12)
# timbre_mean_mean.shape:  (104, 12)
# timbre_mean_var.shape:  (104, 12)
# deezer_MSD/TRAXMAK128E07822CB.h5
# bttimbre.shape:  (466, 12)
# timbre_mean_mean.shape:  (105, 12)
# timbre_mean_var.shape:  (105, 12)
# deezer_MSD/TRADVSU128E0786371.h5
# bttimbre.shape:  (517, 12)
# timbre_mean_mean.shape:  (106, 12)
# timbre_mean_var.shape:  (106, 12)
# deezer_MSD/TRABUCZ128F424163A.h5
# bttimbre.shape:  (563, 12)
# timbre_mean_mean.shape:  (107, 12)
# timbre_mean_var.shape:  (107, 12)
# deezer_MSD/TRAZCOX128F42B6555.h5
# bttimbre.shape:  (560, 12)
# timbre_mean_mean.shape:  (108, 12)
# timbre_mean_var.shape:  (108, 12)
# deezer_MSD/TRAIPST128F9302AE9.h5
# bttimbre.shape:  (868, 12)
# timbre_mean_mean.shape:  (109, 12)
# timbre_mean_var.shape:  (109, 12)
# deezer_MSD/TRAAIHL128F92E6DDA.h5
# bttimbre.shape:  (631, 12)
# timbre_mean_mean.shape:  (110, 12)
# timbre_mean_var.shape:  (110, 12)
# deezer_MSD/TRAEVHU128F92D9EA0.h5
# bttimbre.shape:  (391, 12)
# timbre_mean_mean.shape:  (111, 12)
# timbre_mean_var.shape:  (111, 12)
# deezer_MSD/TRBBXSE128F42798F6.h5
# bttimbre.shape:  (479, 12)
# timbre_mean_mean.shape:  (112, 12)
# timbre_mean_var.shape:  (112, 12)
# deezer_MSD/TRBGRIP128F147FCA6.h5
# bttimbre.shape:  (534, 12)
# timbre_mean_mean.shape:  (113, 12)
# timbre_mean_var.shape:  (113, 12)
# deezer_MSD/TRASRXK128F9311176.h5
# bttimbre.shape:  (372, 12)
# timbre_mean_mean.shape:  (114, 12)
# timbre_mean_var.shape:  (114, 12)
# deezer_MSD/TRALEPN128F9311179.h5
# bttimbre.shape:  (336, 12)
# timbre_mean_mean.shape:  (115, 12)
# timbre_mean_var.shape:  (115, 12)
# deezer_MSD/TRAMGPM128F9311196.h5
# bttimbre.shape:  (564, 12)
# timbre_mean_mean.shape:  (116, 12)
# timbre_mean_var.shape:  (116, 12)
# deezer_MSD/TRANHYE128F92DE232.h5
# bttimbre.shape:  (624, 12)
# timbre_mean_mean.shape:  (117, 12)
# timbre_mean_var.shape:  (117, 12)
# deezer_MSD/TRAJPIQ128F14819A8.h5
# bttimbre.shape:  (530, 12)
# timbre_mean_mean.shape:  (118, 12)
# timbre_mean_var.shape:  (118, 12)
# deezer_MSD/TRAWOHD128F148D176.h5
# bttimbre.shape:  (472, 12)
# timbre_mean_mean.shape:  (119, 12)
# timbre_mean_var.shape:  (119, 12)
# deezer_MSD/TRABFKN12903CAF61B.h5
# bttimbre.shape:  (333, 12)
# timbre_mean_mean.shape:  (120, 12)
# timbre_mean_var.shape:  (120, 12)
# deezer_MSD/TRAXUQL128F932D6C4.h5
# bttimbre.shape:  (554, 12)
# timbre_mean_mean.shape:  (121, 12)
# timbre_mean_var.shape:  (121, 12)
# deezer_MSD/TRARREF128F422FD96.h5
# bttimbre.shape:  (331, 12)
# timbre_mean_mean.shape:  (122, 12)
# timbre_mean_var.shape:  (122, 12)
# deezer_MSD/TRASYQQ128F425092B.h5
# bttimbre.shape:  (1169, 12)
# timbre_mean_mean.shape:  (123, 12)
# timbre_mean_var.shape:  (123, 12)
# deezer_MSD/TRAUYZG12903CDA4E9.h5
# bttimbre.shape:  (627, 12)
# timbre_mean_mean.shape:  (124, 12)
# timbre_mean_var.shape:  (124, 12)
# deezer_MSD/TRARQSD128F427E2AA.h5
# bttimbre.shape:  (461, 12)
# timbre_mean_mean.shape:  (125, 12)
# timbre_mean_var.shape:  (125, 12)
# deezer_MSD/TRAHLDG128F92EB4A9.h5
# bttimbre.shape:  (503, 12)
# timbre_mean_mean.shape:  (126, 12)
# timbre_mean_var.shape:  (126, 12)
# deezer_MSD/TRAGBOR128F92E1064.h5
# bttimbre.shape:  (1387, 12)
# timbre_mean_mean.shape:  (127, 12)
# timbre_mean_var.shape:  (127, 12)
# deezer_MSD/TRAAPFQ128F42684DB.h5
# bttimbre.shape:  (673, 12)
# timbre_mean_mean.shape:  (128, 12)
# timbre_mean_var.shape:  (128, 12)
# deezer_MSD/TRAMKUA128F92ED3E1.h5
# bttimbre.shape:  (666, 12)
# timbre_mean_mean.shape:  (129, 12)
# timbre_mean_var.shape:  (129, 12)
# deezer_MSD/TRAPAZE128F4233355.h5
# bttimbre.shape:  (360, 12)
# timbre_mean_mean.shape:  (130, 12)
# timbre_mean_var.shape:  (130, 12)
# deezer_MSD/TRADVGV128F42BCACE.h5
# bttimbre.shape:  (524, 12)
# timbre_mean_mean.shape:  (131, 12)
# timbre_mean_var.shape:  (131, 12)
# deezer_MSD/TRAFYGO128F42727E7.h5
# bttimbre.shape:  (649, 12)
# timbre_mean_mean.shape:  (132, 12)
# timbre_mean_var.shape:  (132, 12)
# deezer_MSD/TRBALRR128F429625D.h5
# bttimbre.shape:  (352, 12)
# timbre_mean_mean.shape:  (133, 12)
# timbre_mean_var.shape:  (133, 12)
# deezer_MSD/TRAMMDM128F425EAA9.h5
# bttimbre.shape:  (410, 12)
# timbre_mean_mean.shape:  (134, 12)
# timbre_mean_var.shape:  (134, 12)
# deezer_MSD/TRAWSJK128F42767F2.h5
# bttimbre.shape:  (410, 12)
# timbre_mean_mean.shape:  (135, 12)
# timbre_mean_var.shape:  (135, 12)
# deezer_MSD/TRBGZKO128F92DB016.h5
# bttimbre.shape:  (658, 12)
# timbre_mean_mean.shape:  (136, 12)
# timbre_mean_var.shape:  (136, 12)
# deezer_MSD/TRATOAJ128F422F6A7.h5
# bttimbre.shape:  (261, 12)
# timbre_mean_mean.shape:  (137, 12)
# timbre_mean_var.shape:  (137, 12)
# deezer_MSD/TRAWFVE128F42912CA.h5
# bttimbre.shape:  (977, 12)
# timbre_mean_mean.shape:  (138, 12)
# timbre_mean_var.shape:  (138, 12)
# deezer_MSD/TRBEBWG128F93214A4.h5
# bttimbre.shape:  (512, 12)
# timbre_mean_mean.shape:  (139, 12)
# timbre_mean_var.shape:  (139, 12)
# deezer_MSD/TRAAGPH128F4273C8D.h5
# bttimbre.shape:  (167, 12)
# timbre_mean_mean.shape:  (140, 12)
# timbre_mean_var.shape:  (140, 12)
# deezer_MSD/TRBDXIM128F427ABDA.h5
# bttimbre.shape:  (571, 12)
# timbre_mean_mean.shape:  (141, 12)
# timbre_mean_var.shape:  (141, 12)
# deezer_MSD/TRANQLL128F92F5263.h5
# bttimbre.shape:  (371, 12)
# timbre_mean_mean.shape:  (142, 12)
# timbre_mean_var.shape:  (142, 12)
# deezer_MSD/TRAASKQ128F4265E04.h5
# bttimbre.shape:  (470, 12)
# timbre_mean_mean.shape:  (143, 12)
# timbre_mean_var.shape:  (143, 12)
# deezer_MSD/TRBHLBZ128F9300586.h5
# bttimbre.shape:  (691, 12)
# timbre_mean_mean.shape:  (144, 12)
# timbre_mean_var.shape:  (144, 12)
# deezer_MSD/TRADAOM128F4263A78.h5
# bttimbre.shape:  (1029, 12)
# timbre_mean_mean.shape:  (145, 12)
# timbre_mean_var.shape:  (145, 12)
# deezer_MSD/TRAPPUN128F429400B.h5
# bttimbre.shape:  (696, 12)
# timbre_mean_mean.shape:  (146, 12)
# timbre_mean_var.shape:  (146, 12)
# deezer_MSD/TRBCGRI128F93355E9.h5
# bttimbre.shape:  (439, 12)
# timbre_mean_mean.shape:  (147, 12)
# timbre_mean_var.shape:  (147, 12)
# deezer_MSD/TRACUEE128F427EA05.h5
# bttimbre.shape:  (445, 12)
# timbre_mean_mean.shape:  (148, 12)
# timbre_mean_var.shape:  (148, 12)
# deezer_MSD/TRANCFS12903C9B61B.h5
# bttimbre.shape:  (434, 12)
# timbre_mean_mean.shape:  (149, 12)
# timbre_mean_var.shape:  (149, 12)
# deezer_MSD/TRAJFFF128F429874A.h5
# bttimbre.shape:  (576, 12)
# timbre_mean_mean.shape:  (150, 12)
# timbre_mean_var.shape:  (150, 12)
# deezer_MSD/TRADZXK128F429DB92.h5
# bttimbre.shape:  (230, 12)
# timbre_mean_mean.shape:  (151, 12)
# timbre_mean_var.shape:  (151, 12)
# deezer_MSD/TRALPXC128E07819A8.h5
# bttimbre.shape:  (465, 12)
# timbre_mean_mean.shape:  (152, 12)
# timbre_mean_var.shape:  (152, 12)
# deezer_MSD/TRATKVY128EF35F97A.h5
# bttimbre.shape:  (430, 12)
# timbre_mean_mean.shape:  (153, 12)
# timbre_mean_var.shape:  (153, 12)
# deezer_MSD/TRAQAIW12903C9B61E.h5
# bttimbre.shape:  (617, 12)
# timbre_mean_mean.shape:  (154, 12)
# timbre_mean_var.shape:  (154, 12)
# deezer_MSD/TRAYLRS128F427FE81.h5
# bttimbre.shape:  (324, 12)
# timbre_mean_mean.shape:  (155, 12)
# timbre_mean_var.shape:  (155, 12)
# deezer_MSD/TRAUSHD128E0795347.h5
# bttimbre.shape:  (391, 12)
# timbre_mean_mean.shape:  (156, 12)
# timbre_mean_var.shape:  (156, 12)
# deezer_MSD/TRBEBYV128F14A0B65.h5
# bttimbre.shape:  (579, 12)
# timbre_mean_mean.shape:  (157, 12)
# timbre_mean_var.shape:  (157, 12)
# deezer_MSD/TRAUVSF128F14A0B6F.h5
# bttimbre.shape:  (797, 12)
# timbre_mean_mean.shape:  (158, 12)
# timbre_mean_var.shape:  (158, 12)
# deezer_MSD/TRASZUN128F148B165.h5
# bttimbre.shape:  (392, 12)
# timbre_mean_mean.shape:  (159, 12)
# timbre_mean_var.shape:  (159, 12)
# deezer_MSD/TRBDDQF12903CB309A.h5
# bttimbre.shape:  (346, 12)
# timbre_mean_mean.shape:  (160, 12)
# timbre_mean_var.shape:  (160, 12)
# deezer_MSD/TRBEYJR128F4292651.h5
# bttimbre.shape:  (351, 12)
# timbre_mean_mean.shape:  (161, 12)
# timbre_mean_var.shape:  (161, 12)
# deezer_MSD/TRAZWGV128F425DA7C.h5
# bttimbre.shape:  (359, 12)
# timbre_mean_mean.shape:  (162, 12)
# timbre_mean_var.shape:  (162, 12)
# deezer_MSD/TRADQAR128F92ED3DC.h5
# bttimbre.shape:  (684, 12)
# timbre_mean_mean.shape:  (163, 12)
# timbre_mean_var.shape:  (163, 12)
# deezer_MSD/TRBIFGK128F92F23A2.h5
# bttimbre.shape:  (497, 12)
# timbre_mean_mean.shape:  (164, 12)
# timbre_mean_var.shape:  (164, 12)
# deezer_MSD/TRAKTWZ128EF35E206.h5
# bttimbre.shape:  (450, 12)
# timbre_mean_mean.shape:  (165, 12)
# timbre_mean_var.shape:  (165, 12)
# deezer_MSD/TRBBEGG128F9314BAA.h5
# bttimbre.shape:  (576, 12)
# timbre_mean_mean.shape:  (166, 12)
# timbre_mean_var.shape:  (166, 12)
# deezer_MSD/TRAWULX128F4291255.h5
# bttimbre.shape:  (725, 12)
# timbre_mean_mean.shape:  (167, 12)
# timbre_mean_var.shape:  (167, 12)
# deezer_MSD/TRARODV128F1460DBC.h5
# bttimbre.shape:  (622, 12)
# timbre_mean_mean.shape:  (168, 12)
# timbre_mean_var.shape:  (168, 12)
# deezer_MSD/TRAWWQM128F148C796.h5
# bttimbre.shape:  (703, 12)
# timbre_mean_mean.shape:  (169, 12)
# timbre_mean_var.shape:  (169, 12)
# deezer_MSD/TRASWFP128E0789E6C.h5
# bttimbre.shape:  (508, 12)
# timbre_mean_mean.shape:  (170, 12)
# timbre_mean_var.shape:  (170, 12)
# deezer_MSD/TRAFAIB128F426E636.h5
# bttimbre.shape:  (310, 12)
# timbre_mean_mean.shape:  (171, 12)
# timbre_mean_var.shape:  (171, 12)
# deezer_MSD/TRAIZQI128F42A51F9.h5
# bttimbre.shape:  (296, 12)
# timbre_mean_mean.shape:  (172, 12)
# timbre_mean_var.shape:  (172, 12)
# deezer_MSD/TRARMUI128F147162F.h5
# bttimbre.shape:  (393, 12)
# timbre_mean_mean.shape:  (173, 12)
# timbre_mean_var.shape:  (173, 12)
# deezer_MSD/TRBIJMU12903CF892B.h5
# bttimbre.shape:  (911, 12)
# timbre_mean_mean.shape:  (174, 12)
# timbre_mean_var.shape:  (174, 12)
# deezer_MSD/TRANLHL12903CF88E5.h5
# bttimbre.shape:  (622, 12)
# timbre_mean_mean.shape:  (175, 12)
# timbre_mean_var.shape:  (175, 12)
# deezer_MSD/TRBGRXO128F4282115.h5
# bttimbre.shape:  (815, 12)
# timbre_mean_mean.shape:  (176, 12)
# timbre_mean_var.shape:  (176, 12)
# deezer_MSD/TRALQZK128F429802D.h5
# bttimbre.shape:  (295, 12)
# timbre_mean_mean.shape:  (177, 12)
# timbre_mean_var.shape:  (177, 12)
# deezer_MSD/TRBIBGN128F42ADC66.h5
# bttimbre.shape:  (422, 12)
# timbre_mean_mean.shape:  (178, 12)
# timbre_mean_var.shape:  (178, 12)
# deezer_MSD/TRAVMRI128F4259E76.h5
# bttimbre.shape:  (362, 12)
# timbre_mean_mean.shape:  (179, 12)
# timbre_mean_var.shape:  (179, 12)
# deezer_MSD/TRBDWRY128F427991E.h5
# bttimbre.shape:  (1044, 12)
# timbre_mean_mean.shape:  (180, 12)
# timbre_mean_var.shape:  (180, 12)
# deezer_MSD/TRAFOKY128F4276D91.h5
# bttimbre.shape:  (337, 12)
# timbre_mean_mean.shape:  (181, 12)
# timbre_mean_var.shape:  (181, 12)
# deezer_MSD/TRADXMA128F4276D94.h5
# bttimbre.shape:  (254, 12)
# timbre_mean_mean.shape:  (182, 12)
# timbre_mean_var.shape:  (182, 12)
# deezer_MSD/TRBBQFV128F4252EFF.h5
# bttimbre.shape:  (942, 12)
# timbre_mean_mean.shape:  (183, 12)
# timbre_mean_var.shape:  (183, 12)
# deezer_MSD/TRBEAMO128F425B75F.h5
# bttimbre.shape:  (527, 12)
# timbre_mean_mean.shape:  (184, 12)
# timbre_mean_var.shape:  (184, 12)
# deezer_MSD/TRACKAP128F425B741.h5
# bttimbre.shape:  (877, 12)
# timbre_mean_mean.shape:  (185, 12)
# timbre_mean_var.shape:  (185, 12)
# deezer_MSD/TRAAGEC128E079252C.h5
# bttimbre.shape:  (444, 12)
# timbre_mean_mean.shape:  (186, 12)
# timbre_mean_var.shape:  (186, 12)
# deezer_MSD/TRBABQW128F148C7FB.h5
# bttimbre.shape:  (875, 12)
# timbre_mean_mean.shape:  (187, 12)
# timbre_mean_var.shape:  (187, 12)
# deezer_MSD/TRAEZLQ128F427F954.h5
# bttimbre.shape:  (470, 12)
# timbre_mean_mean.shape:  (188, 12)
# timbre_mean_var.shape:  (188, 12)
# deezer_MSD/TRAECVW128E078884D.h5
# bttimbre.shape:  (288, 12)
# timbre_mean_mean.shape:  (189, 12)
# timbre_mean_var.shape:  (189, 12)
# deezer_MSD/TRAWRKT128E0788857.h5
# bttimbre.shape:  (591, 12)
# timbre_mean_mean.shape:  (190, 12)
# timbre_mean_var.shape:  (190, 12)
# deezer_MSD/TRACNAS128F14567C6.h5
# bttimbre.shape:  (759, 12)
# timbre_mean_mean.shape:  (191, 12)
# timbre_mean_var.shape:  (191, 12)
# deezer_MSD/TRAWTGS128F14569A8.h5
# bttimbre.shape:  (309, 12)
# timbre_mean_mean.shape:  (192, 12)
# timbre_mean_var.shape:  (192, 12)
# deezer_MSD/TRAKQXJ128F147A028.h5
# bttimbre.shape:  (522, 12)
# timbre_mean_mean.shape:  (193, 12)
# timbre_mean_var.shape:  (193, 12)
# deezer_MSD/TRBBQPP128F92EE611.h5
# bttimbre.shape:  (788, 12)
# timbre_mean_mean.shape:  (194, 12)
# timbre_mean_var.shape:  (194, 12)
# deezer_MSD/TRANCJG128F14528B4.h5
# bttimbre.shape:  (551, 12)
# timbre_mean_mean.shape:  (195, 12)
# timbre_mean_var.shape:  (195, 12)
# deezer_MSD/TRBESBZ12903CA0A95.h5
# bttimbre.shape:  (491, 12)
# timbre_mean_mean.shape:  (196, 12)
# timbre_mean_var.shape:  (196, 12)
# deezer_MSD/TRAMRFE128F4267DF3.h5
# bttimbre.shape:  (433, 12)
# timbre_mean_mean.shape:  (197, 12)
# timbre_mean_var.shape:  (197, 12)
# deezer_MSD/TRAMESI128F93509F7.h5
# bttimbre.shape:  (425, 12)
# timbre_mean_mean.shape:  (198, 12)
# timbre_mean_var.shape:  (198, 12)
# deezer_MSD/TRALBIA128F4272082.h5
# bttimbre.shape:  (441, 12)
# timbre_mean_mean.shape:  (199, 12)
# timbre_mean_var.shape:  (199, 12)
# deezer_MSD/TRAMCJI128F93335AF.h5
# bttimbre.shape:  (375, 12)
# timbre_mean_mean.shape:  (200, 12)
# timbre_mean_var.shape:  (200, 12)
# deezer_MSD/TRAVMXD12903CBBD0B.h5
# bttimbre.shape:  (678, 12)
# timbre_mean_mean.shape:  (201, 12)
# timbre_mean_var.shape:  (201, 12)
# deezer_MSD/TRAEUIW12903D018F0.h5
# bttimbre.shape:  (345, 12)
# timbre_mean_mean.shape:  (202, 12)
# timbre_mean_var.shape:  (202, 12)
# deezer_MSD/TRARANL128F1478789.h5
# bttimbre.shape:  (617, 12)
# timbre_mean_mean.shape:  (203, 12)
# timbre_mean_var.shape:  (203, 12)
# deezer_MSD/TRAPEIN128E078892E.h5
# bttimbre.shape:  (270, 12)
# timbre_mean_mean.shape:  (204, 12)
# timbre_mean_var.shape:  (204, 12)
# deezer_MSD/TRASWIV128E0788A84.h5
# bttimbre.shape:  (605, 12)
# timbre_mean_mean.shape:  (205, 12)
# timbre_mean_var.shape:  (205, 12)
# deezer_MSD/TRAERPT128F931103E.h5
# bttimbre.shape:  (306, 12)
# timbre_mean_mean.shape:  (206, 12)
# timbre_mean_var.shape:  (206, 12)
# deezer_MSD/TRALTKQ128F932DA67.h5
# bttimbre.shape:  (410, 12)
# timbre_mean_mean.shape:  (207, 12)
# timbre_mean_var.shape:  (207, 12)
# deezer_MSD/TRAQQHJ128F9345DC3.h5
# bttimbre.shape:  (487, 12)
# timbre_mean_mean.shape:  (208, 12)
# timbre_mean_var.shape:  (208, 12)
# deezer_MSD/TRBBCUA128E078FA50.h5
# bttimbre.shape:  (503, 12)
# timbre_mean_mean.shape:  (209, 12)
# timbre_mean_var.shape:  (209, 12)
# deezer_MSD/TRBCUBV128F145F7E9.h5
# bttimbre.shape:  (458, 12)
# timbre_mean_mean.shape:  (210, 12)
# timbre_mean_var.shape:  (210, 12)
# deezer_MSD/TRBIGRY128F42597B3.h5
# bttimbre.shape:  (405, 12)
# timbre_mean_mean.shape:  (211, 12)
# timbre_mean_var.shape:  (211, 12)
# deezer_MSD/TRBCNGI128F42597B4.h5
# bttimbre.shape:  (491, 12)
# timbre_mean_mean.shape:  (212, 12)
# timbre_mean_var.shape:  (212, 12)
# deezer_MSD/TRAZDTT128F9346306.h5
# bttimbre.shape:  (278, 12)
# timbre_mean_mean.shape:  (213, 12)
# timbre_mean_var.shape:  (213, 12)
# deezer_MSD/TRARVEY128F9300AC3.h5
# bttimbre.shape:  (716, 12)
# timbre_mean_mean.shape:  (214, 12)
# timbre_mean_var.shape:  (214, 12)
# deezer_MSD/TRASNOT128E0791785.h5
# bttimbre.shape:  (367, 12)
# timbre_mean_mean.shape:  (215, 12)
# timbre_mean_var.shape:  (215, 12)
# deezer_MSD/TRAPHZT128F147A02B.h5
# bttimbre.shape:  (634, 12)
# timbre_mean_mean.shape:  (216, 12)
# timbre_mean_var.shape:  (216, 12)
# deezer_MSD/TRALIHL128E0791C9A.h5
# bttimbre.shape:  (993, 12)
# timbre_mean_mean.shape:  (217, 12)
# timbre_mean_var.shape:  (217, 12)
# deezer_MSD/TRAPGKY128F42972A9.h5
# bttimbre.shape:  (312, 12)
# timbre_mean_mean.shape:  (218, 12)
# timbre_mean_var.shape:  (218, 12)
# deezer_MSD/TRAIELD128F92DC682.h5
# bttimbre.shape:  (349, 12)
# timbre_mean_mean.shape:  (219, 12)
# timbre_mean_var.shape:  (219, 12)
# deezer_MSD/TRAHZMM128E07838FF.h5
# bttimbre.shape:  (386, 12)
# timbre_mean_mean.shape:  (220, 12)
# timbre_mean_var.shape:  (220, 12)
# deezer_MSD/TRAFRYJ128F92E638B.h5
# bttimbre.shape:  (988, 12)
# timbre_mean_mean.shape:  (221, 12)
# timbre_mean_var.shape:  (221, 12)
# deezer_MSD/TRBCANP128F92FA6B9.h5
# bttimbre.shape:  (504, 12)
# timbre_mean_mean.shape:  (222, 12)
# timbre_mean_var.shape:  (222, 12)
# deezer_MSD/TRBAXDP12903CD1922.h5
# bttimbre.shape:  (576, 12)
# timbre_mean_mean.shape:  (223, 12)
# timbre_mean_var.shape:  (223, 12)
# deezer_MSD/TRAAEEH128E0795DFE.h5
# bttimbre.shape:  (716, 12)
# timbre_mean_mean.shape:  (224, 12)
# timbre_mean_var.shape:  (224, 12)

# %% [markdown]
# ### Q1-2. Linear Regression using means and vars of means (for each beat) of timbre, chroma, and loudmax  (1pt)

# %% [markdown]
# Report R squared scores and mean squared error of the best linear model that describes valence when the following features were used.
#
# timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var.

# %%
# Out:
# Coefficient of determination: 0.31
# Mean squared error: 0.77

# %% [markdown]
# Report R squared scores and mean squared error of the best linear model that describes arousal when the following features were used.
#
# timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var.

# %%
# Out:
# Coefficient of determination: 0.40
# Mean squared error: 0.54

# %% [markdown]
# ### Q1-3. Linear Regression using 1) means and vars of timbre, chroma, and loudmax and 2)means and vars of means (for each beat) of timbre, chroma, and loudmax (1pt)

# %% [markdown]
# Report R squared scores and mean squared error of the best linear model that describes valence when the following features were used.
#
# timbre_mean,timbre_var,chroma_mean,chroma_var, loudmax_mean, loudmax_var, timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var

# %%
# Out:
# Coefficient of determination: 0.52
# Mean squared error: 0.54

# %% [markdown]
# Report R squared scores and mean squared error of the best linear model that describes arousal when the following features were used.
#
# timbre_mean,timbre_var,chroma_mean,chroma_var, loudmax_mean, loudmax_var, timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var

# %%
# Out:
# Coefficient of determination: 0.60
# Mean squared error: 0.36

# %% [markdown]
# ### Q1-4. Softmax Regression using 1) means and vars of timbre, chroma, and loudmax and 2)means and vars of means (for each beat) of timbre, chroma, and loudmax (1pt)

# %% [markdown]
# * Build a softmax regression classifier to solve the music mood classification problem. The four mood classes are four quadrants of Russell’s emotion circumplex.
#
# * Use 10% of the dataset for the test set. Report classification scores of the training set and the test set.
#
#
# * Use the following features:
# timbre_mean,timbre_var,chroma_mean,chroma_var, loudmax_mean, loudmax_var, timbre_mean_mean, timbre_mean_var, chroma_mean_mean, chroma_mean_var, loudmax_mean_mean, loudmax_mean_var

# %% [markdown]
# # Q2. Explore MSD features

# %% [markdown]
# You can see an example track description from the following link http://millionsongdataset.com/pages/example-track-description/. The table on the webpage shows a list of fields in an example MSD hd5 file. Some of them are metadata, such as artist information, and some are features such as timbre and loudness. Explore features of Deezer MSD Mood Dataset II after loading them using hdf5_getters.open_h5_file_read(filename) and hdf5_getters.get_FEATURENAME(h5). In particular, pick three features and report their summary information using data.hist() and data.describe() functions of pandas.
#
# You can also read the ISMIR MSD paper (http://ismir2011.ismir.net/papers/OS6-1.pdf) to get deeper understanding of the MSD.
#
# Deliverable: Summary information of three MSD features of your interest  (1pt)

# %% [markdown]
# # Q3. Find one MIR paper that used MSD and write a one-paragraph summary of it.

# %% [markdown]
# To find a paper, use https://scholar.google.com. Some possible search keywords are:
#
# - million song dataset ismir
# - million song dataset ismir chord
# - million song dataset cover
#
# Deliverable: A link to the paper and your one-paragraph summary/introduction of it (just a few sentences would be sufficient). Some possible questions that you can answer are:
#
# - What problem did they solve?
# - Which features did they use?
# - What is the most interesting takeaway message from the paper?  (1pt)
